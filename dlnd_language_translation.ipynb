# %% [markdown]
# # Language Translation
# In this project, you’re going to take a peek into the realm of neural network machine translation.  You’ll be training a sequence to sequence model on a dataset of English and French sentences that can translate new sentences from English to French.
# ## Get the Data
# Since translating the whole language of English to French will take lots of time to train, we have provided you with a small portion of the English corpus.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import helper
import problem_unittests as tests

source_path = 'data/small_vocab_en'
target_path = 'data/small_vocab_fr'
source_text = helper.load_data(source_path)
target_text = helper.load_data(target_path)

# %% [markdown]
# ## Explore the Data
# Play around with view_sentence_range to view different parts of the data.

# %%
view_sentence_range = (0, 10)

"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np

print('Dataset Stats')
print('Roughly the number of unique words: {}'.format(len({word: None for word in source_text.split()})))

sentences = source_text.split('\n')
word_counts = [len(sentence.split()) for sentence in sentences]
print('Number of sentences: {}'.format(len(sentences)))
print('Average number of words in a sentence: {}'.format(np.average(word_counts)))

print()
print('English sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(source_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
print()
print('French sentences {} to {}:'.format(*view_sentence_range))
print('\n'.join(target_text.split('\n')[view_sentence_range[0]:view_sentence_range[1]]))
# Out:
# Dataset Stats
# Roughly the number of unique words: 227
# Number of sentences: 137861
# Average number of words in a sentence: 13.225277634719028
#
# English sentences 0 to 10:
# new jersey is sometimes quiet during autumn , and it is snowy in april .
# the united states is usually chilly during july , and it is usually freezing in november .
# california is usually quiet during march , and it is usually hot in june .
# the united states is sometimes mild during june , and it is cold in september .
# your least liked fruit is the grape , but my least liked is the apple .
# his favorite fruit is the orange , but my favorite is the grape .
# paris is relaxing during december , but it is usually chilly in july .
# new jersey is busy during spring , and it is never hot in march .
# our least liked fruit is the lemon , but my least liked is the grape .
# the united states is sometimes busy during january , and it is sometimes warm in november .
#
# French sentences 0 to 10:
# new jersey est parfois calme pendant l' automne , et il est neigeux en avril .
# les états-unis est généralement froid en juillet , et il gèle habituellement en novembre .
# california est généralement calme en mars , et il est généralement chaud en juin .
# les états-unis est parfois légère en juin , et il fait froid en septembre .
# votre moins aimé fruit est le raisin , mais mon moins aimé est la pomme .
# son fruit préféré est l'orange , mais mon préféré est le raisin .
# paris est relaxant en décembre , mais il est généralement froid en juillet .
# new jersey est occupé au printemps , et il est jamais chaude en mars .
# notre fruit est moins aimé le citron , mais mon moins aimé est le raisin .
# les états-unis est parfois occupé en janvier , et il est parfois chaud en novembre .

# %% [markdown]
# ## Implement Preprocessing Function
# ### Text to Word Ids
# As you did with other RNNs, you must turn the text into a number so the computer can understand it. In the function `text_to_ids()`, you'll turn `source_text` and `target_text` from words to ids.  However, you need to add the `<EOS>` word id at the end of `target_text`.  This will help the neural network predict when the sentence should end.
#
# You can get the `<EOS>` word id by doing:
# ```python
# target_vocab_to_int['<EOS>']
# ```
# You can get other word ids using `source_vocab_to_int` and `target_vocab_to_int`.

# %%
def text_to_ids(source_text, target_text, source_vocab_to_int, target_vocab_to_int):
    """
    Convert source and target text to proper word ids
    :param source_text: String that contains all the source text.
    :param target_text: String that contains all the target text.
    :param source_vocab_to_int: Dictionary to go from the source words to an id
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: A tuple of lists (source_id_text, target_id_text)
    """
    source_id_text=list()
    for sentence in source_text.split("\n"):
        source_id_text.append([source_vocab_to_int[word] for word in sentence.split()])
  
    target_id_text=list()
    for sentence in target_text.split("\n"):
        target_id_text.append([target_vocab_to_int[word] for word in sentence.split()]+ [target_vocab_to_int['<EOS>']])
  
    
    return source_id_text, target_id_text

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_text_to_ids(text_to_ids)
# Out:
# Tests Passed

# %% [markdown]
# ### Preprocess all the data and save it
# Running the code cell below will preprocess all the data and save it to file.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
helper.preprocess_and_save_data(source_path, target_path, text_to_ids)

# %% [markdown]
# # Check Point
# This is your first checkpoint. If you ever decide to come back to this notebook or have to restart the notebook, you can start from here. The preprocessed data has been saved to disk.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import numpy as np
import helper
import problem_unittests as tests

(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()

# %% [markdown]
# ### Check the Version of TensorFlow and Access to GPU
# This will check to make sure you have the correct version of TensorFlow and access to a GPU

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
from distutils.version import LooseVersion
import warnings
import tensorflow as tf
from tensorflow.python.layers.core import Dense

# Check TensorFlow Version
assert LooseVersion(tf.__version__) >= LooseVersion('1.1'), 'Please use TensorFlow version 1.1 or newer'
print('TensorFlow Version: {}'.format(tf.__version__))

# Check for a GPU
if not tf.test.gpu_device_name():
    warnings.warn('No GPU found. Please use a GPU to train your neural network.')
else:
    print('Default GPU Device: {}'.format(tf.test.gpu_device_name()))
# Out:
# TensorFlow Version: 1.3.0
# Default GPU Device: /gpu:0

# %% [markdown]
# ## Build the Neural Network
# You'll build the components necessary to build a Sequence-to-Sequence model by implementing the following functions below:
# - `model_inputs`
# - `process_decoder_input`
# - `encoding_layer`
# - `decoding_layer_train`
# - `decoding_layer_infer`
# - `decoding_layer`
# - `seq2seq_model`
#
# ### Input
# Implement the `model_inputs()` function to create TF Placeholders for the Neural Network. It should create the following placeholders:
#
# - Input text placeholder named "input" using the TF Placeholder name parameter with rank 2.
# - Targets placeholder with rank 2.
# - Learning rate placeholder with rank 0.
# - Keep probability placeholder named "keep_prob" using the TF Placeholder name parameter with rank 0.
# - Target sequence length placeholder named "target_sequence_length" with rank 1
# - Max target sequence length tensor named "max_target_len" getting its value from applying tf.reduce_max on the target_sequence_length placeholder. Rank 0.
# - Source sequence length placeholder named "source_sequence_length" with rank 1
#
# Return the placeholders in the following the tuple (input, targets, learning rate, keep probability, target sequence length, max target sequence length, source sequence length)

# %%
def model_inputs():
    """
    Create TF Placeholders for input, targets, learning rate, and 
    lengths of source and target sequences.
    :return: Tuple (input, targets, learning rate, keep probability, target sequence length,
    max target sequence length, source sequence length)
    """
    inputs =tf.placeholder(shape=[None, None], dtype=tf.int32, name='input')
    targets=tf.placeholder(shape=[None, None], dtype=tf.int32, name='targets')
    learning_rate=tf.placeholder(dtype=tf.float32, name='learning_rate')
    keep_prob=tf.placeholder(dtype=tf.float32, name='keep_prob')
    
    source_sequence_length=tf.placeholder(tf.int32, shape=[None], name='source_sequence_length')
    target_sequence_length=tf.placeholder(tf.int32, shape=[None], name='target_sequence_length')
    
    max_target_len=tf.reduce_max(target_sequence_length)
    
    
    return inputs, targets, learning_rate, keep_prob, target_sequence_length, max_target_len, source_sequence_length


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_model_inputs(model_inputs)
# Out:
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_2/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "/usr/lib/python3.5/runpy.py", line 184, in _run_module_as_main\n    "__main__", mod_spec)', 'File "/usr/lib/python3.5/runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "/usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py", line 16, in <module>\n    app.launch_new_instance()', 'File "/usr/local/lib/python3.5/dist-packages/traitlets/config/application.py", line 658, in launch_instance\n    app.start()', 'File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelapp.py", line 477, in start\n    ioloop.IOLoop.instance().start()', 'File "/usr/local/lib/python3.5/dist-packages/zmq/eventloop/ioloop.py", line 177, in start\n    super(ZMQIOLoop, self).start()', 'File "/usr/local/lib/python3.5/dist-packages/tornado/ioloop.py", line 888, in start\n    handler_func(fd_obj, events)', 'File "/usr/local/lib/python3.5/dist-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/usr/local/lib/python3.5/dist-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events\n    self._handle_recv()', 'File "/usr/local/lib/python3.5/dist-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv\n    self._run_callback(callback, msg)', 'File "/usr/local/lib/python3.5/dist-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback\n    callback(*args, **kwargs)', 'File "/usr/local/lib/python3.5/dist-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell\n    handler(stream, idents, msg)', 'File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request\n    user_expressions, allow_stdin)', 'File "/usr/local/lib/python3.5/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "/usr/local/lib/python3.5/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2728, in run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2856, in run_ast_nodes\n    if self.run_code(code, result):', 'File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2910, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-9-c345202c802b>", line 25, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "/home/ubuntu/deep-learning/language-translation/problem_unittests.py", line 106, in test_model_inputs\n    assert tf.assert_rank(lr, 0, message=\'Learning Rate has wrong rank\')', 'File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/check_ops.py", line 571, in _assert_rank_condition\n    return control_flow_ops.Assert(condition, data, summarize=summarize)', 'File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/util/tf_should_use.py", line 175, in wrapped\n    return _add_should_use_warning(fn(*args, **kwargs))', 'File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/util/tf_should_use.py", line 144, in _add_should_use_warning\n    wrapped = TFShouldUseWarningWrapper(x)', 'File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/util/tf_should_use.py", line 101, in __init__\n    stack = [s.strip() for s in traceback.format_stack()]']
# ==================================
# ERROR:tensorflow:==================================
# Object was never used (type <class 'tensorflow.python.framework.ops.Operation'>):
# <tf.Operation 'assert_rank_3/Assert/Assert' type=Assert>
# If you want to mark it as used call its "mark_used()" method.
# It was originally created here:
# ['File "/usr/lib/python3.5/runpy.py", line 184, in _run_module_as_main\n    "__main__", mod_spec)', 'File "/usr/lib/python3.5/runpy.py", line 85, in _run_code\n    exec(code, run_globals)', 'File "/usr/local/lib/python3.5/dist-packages/ipykernel_launcher.py", line 16, in <module>\n    app.launch_new_instance()', 'File "/usr/local/lib/python3.5/dist-packages/traitlets/config/application.py", line 658, in launch_instance\n    app.start()', 'File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelapp.py", line 477, in start\n    ioloop.IOLoop.instance().start()', 'File "/usr/local/lib/python3.5/dist-packages/zmq/eventloop/ioloop.py", line 177, in start\n    super(ZMQIOLoop, self).start()', 'File "/usr/local/lib/python3.5/dist-packages/tornado/ioloop.py", line 888, in start\n    handler_func(fd_obj, events)', 'File "/usr/local/lib/python3.5/dist-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/usr/local/lib/python3.5/dist-packages/zmq/eventloop/zmqstream.py", line 440, in _handle_events\n    self._handle_recv()', 'File "/usr/local/lib/python3.5/dist-packages/zmq/eventloop/zmqstream.py", line 472, in _handle_recv\n    self._run_callback(callback, msg)', 'File "/usr/local/lib/python3.5/dist-packages/zmq/eventloop/zmqstream.py", line 414, in _run_callback\n    callback(*args, **kwargs)', 'File "/usr/local/lib/python3.5/dist-packages/tornado/stack_context.py", line 277, in null_wrapper\n    return fn(*args, **kwargs)', 'File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 283, in dispatcher\n    return self.dispatch_shell(stream, msg)', 'File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 235, in dispatch_shell\n    handler(stream, idents, msg)', 'File "/usr/local/lib/python3.5/dist-packages/ipykernel/kernelbase.py", line 399, in execute_request\n    user_expressions, allow_stdin)', 'File "/usr/local/lib/python3.5/dist-packages/ipykernel/ipkernel.py", line 196, in do_execute\n    res = shell.run_cell(code, store_history=store_history, silent=silent)', 'File "/usr/local/lib/python3.5/dist-packages/ipykernel/zmqshell.py", line 533, in run_cell\n    return super(ZMQInteractiveShell, self).run_cell(*args, **kwargs)', 'File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2728, in run_cell\n    interactivity=interactivity, compiler=compiler, result=result)', 'File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2856, in run_ast_nodes\n    if self.run_code(code, result):', 'File "/usr/local/lib/python3.5/dist-packages/IPython/core/interactiveshell.py", line 2910, in run_code\n    exec(code_obj, self.user_global_ns, self.user_ns)', 'File "<ipython-input-9-c345202c802b>", line 25, in <module>\n    tests.test_model_inputs(model_inputs)', 'File "/home/ubuntu/deep-learning/language-translation/problem_unittests.py", line 107, in test_model_inputs\n    assert tf.assert_rank(keep_prob, 0, message=\'Keep Probability has wrong rank\')', 'File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/check_ops.py", line 617, in assert_rank\n    dynamic_condition, data, summarize)', 'File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/ops/check_ops.py", line 571, in _assert_rank_condition\n    return control_flow_ops.Assert(condition, data, summarize=summarize)', 'File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/util/tf_should_use.py", line 175, in wrapped\n    return _add_should_use_warning(fn(*args, **kwargs))', 'File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/util/tf_should_use.py", line 144, in _add_should_use_warning\n    wrapped = TFShouldUseWarningWrapper(x)', 'File "/usr/local/lib/python3.5/dist-packages/tensorflow/python/util/tf_should_use.py", line 101, in __init__\n    stack = [s.strip() for s in traceback.format_stack()]']
# ==================================
# Tests Passed

# %% [markdown]
# ### Process Decoder Input
# Implement `process_decoder_input` by removing the last word id from each batch in `target_data` and concat the GO ID to the begining of each batch.

# %%
def process_decoder_input(target_data, target_vocab_to_int, batch_size):
    """
    Preprocess target data for encoding
    :param target_data: Target Placehoder
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param batch_size: Batch Size
    :return: Preprocessed target data
    """
    #Implementation: Remove the last word id from each batch by using strided slice
    ##### Strided slice --> tf.strided_slice(tensor, begin, end, strides)
    ending = tf.strided_slice(target_data, [0,0], [batch_size, -1], [1, 1])
    dec_input = tf.concat([tf.fill([batch_size, 1], target_vocab_to_int['<GO>']), ending], 1)                                 
    return dec_input 

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_process_encoding_input(process_decoder_input)
# Out:
# Tests Passed

# %% [markdown]
# ### Encoding
# Implement `encoding_layer()` to create a Encoder RNN layer:
#  * Embed the encoder input using [`tf.contrib.layers.embed_sequence`](https://www.tensorflow.org/api_docs/python/tf/contrib/layers/embed_sequence)
#  * Construct a [stacked](https://github.com/tensorflow/tensorflow/blob/6947f65a374ebf29e74bb71e36fd82760056d82c/tensorflow/docs_src/tutorials/recurrent.md#stacking-multiple-lstms) [`tf.contrib.rnn.LSTMCell`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/LSTMCell) wrapped in a [`tf.contrib.rnn.DropoutWrapper`](https://www.tensorflow.org/api_docs/python/tf/contrib/rnn/DropoutWrapper)
#  * Pass cell and embedded input to [`tf.nn.dynamic_rnn()`](https://www.tensorflow.org/api_docs/python/tf/nn/dynamic_rnn)

# %%
from imp import reload
reload(tests)

def encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob, 
                   source_sequence_length, source_vocab_size, 
                   encoding_embedding_size):
    """
    Create encoding layer
    :param rnn_inputs: Inputs for the RNN
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param keep_prob: Dropout keep probability
    :param source_sequence_length: a list of the lengths of each sequence in the batch
    :param source_vocab_size: vocabulary size of source data
    :param encoding_embedding_size: embedding size of source data
    :return: tuple (RNN output, RNN state)
    """
    #Implementation: 
    #### Generate the embedded input using tf.contrib.layers.embed_sequence
    #### tf.contrib.layers.embed_sequence(ids, vocab_size, embed_dim )
    ######## ids --> Tensor of type int32 or int64 representing the input ids; if text, converted to ints
    ######## vocab size  --> integer number of symbols in vocabulary
    ######## embed_dim --> integer number of dimensions for the embedding matrix
    enc_embed_input = tf.contrib.layers.embed_sequence(rnn_inputs, source_vocab_size, encoding_embedding_size)
    
    ##### Generate the RNN cell
    def make_cell(rnn_size):
        enc_cell = tf.contrib.rnn.LSTMCell(rnn_size, initializer=tf.random_uniform_initializer(-0.1, 0.1, seed =2))
        return enc_cell
    
    enc_cell = tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
    
    enc_output, enc_state = tf.nn.dynamic_rnn(enc_cell, enc_embed_input, sequence_length=source_sequence_length, dtype=tf.float32)
    
    return enc_output, enc_state

"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_encoding_layer(encoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Training
# Create a training decoding layer:
# * Create a [`tf.contrib.seq2seq.TrainingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/TrainingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_train(encoder_state, dec_cell, dec_embed_input, 
                         target_sequence_length, max_summary_length, 
                         output_layer, keep_prob):
    """
    Create a decoding layer for training
    :param encoder_state: Encoder State
    :param dec_cell: Decoder RNN Cell
    :param dec_embed_input: Decoder embedded input
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_summary_length: The length of the longest sequence in the batch
    :param output_layer: Function to apply the output layer
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing training logits and sample_id
    """
    #Implementation
    ## Decoder created using the tf.contrib.seq2seq.BasicDecoder and 
    ## tf.contrib.seq2seq.dynamic_decode methods
    ## Target sequences are fed as inputs to the training decoder @ each step to make it more robust
    ## Training decoder does not feed output of each time step to the next
    
    #Helper for the training process. Used by BasicDecoder to read inputs
    training_helper=tf.contrib.seq2seq.TrainingHelper(inputs=dec_embed_input,
                                                     sequence_length=target_sequence_length,
                                                     time_major=False)
    
    #Basic decoder
    training_decoder=tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                    training_helper,
                                                    encoder_state,
                                                    output_layer)
    #Perform dynamic decoding using the decoder
    training_decoder_output=tf.contrib.seq2seq.dynamic_decode(training_decoder,
                                                            impute_finished=True,
                                                            maximum_iterations=max_summary_length)[0]
    
    return training_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_train(decoding_layer_train)
# Out:
# Tests Passed

# %% [markdown]
# ### Decoding - Inference
# Create inference decoder:
# * Create a [`tf.contrib.seq2seq.GreedyEmbeddingHelper`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/GreedyEmbeddingHelper)
# * Create a [`tf.contrib.seq2seq.BasicDecoder`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/BasicDecoder)
# * Obtain the decoder outputs from [`tf.contrib.seq2seq.dynamic_decode`](https://www.tensorflow.org/api_docs/python/tf/contrib/seq2seq/dynamic_decode)

# %%
def decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id,
                         end_of_sequence_id, max_target_sequence_length,
                         vocab_size, output_layer, batch_size, keep_prob):
    """
    Create a decoding layer for inference
    :param encoder_state: Encoder state
    :param dec_cell: Decoder RNN Cell
    :param dec_embeddings: Decoder embeddings
    :param start_of_sequence_id: GO ID
    :param end_of_sequence_id: EOS Id
    :param max_target_sequence_length: Maximum length of target sequences
    :param vocab_size: Size of decoder/target vocabulary
    :param decoding_scope: TenorFlow Variable Scope for decoding
    :param output_layer: Function to apply the output layer
    :param batch_size: Batch size
    :param keep_prob: Dropout keep probability
    :return: BasicDecoderOutput containing inference logits and sample_id
    """
    # Implementation
    ## Hand over the encoder hidden state to the inference decoder.
    ## Feed output of each step to the next
    
    start_tokens = tf.tile(tf.constant([start_of_sequence_id], dtype=tf.int32), [batch_size], name='start_tokens')
    # Helper for the inference process
    inference_helper= tf.contrib.seq2seq.GreedyEmbeddingHelper(dec_embeddings,
                                                              start_tokens,
                                                               end_of_sequence_id)
    # Basic Decoder
    inference_decoder = tf.contrib.seq2seq.BasicDecoder(dec_cell,
                                                       inference_helper,
                                                       encoder_state,
                                                       output_layer)
    #Perform dynamic decoding using hte decoder
    inference_decoder_output = tf.contrib.seq2seq.dynamic_decode(inference_decoder,
                                                                impute_finished=True,
                                                                maximum_iterations=max_target_sequence_length)[0]
    return inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer_infer(decoding_layer_infer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Decoding Layer
# Implement `decoding_layer()` to create a Decoder RNN layer.
#
# * Embed the target sequences
# * Construct the decoder LSTM cell (just like you constructed the encoder cell above)
# * Create an output layer to map the outputs of the decoder to the elements of our vocabulary
# * Use the your `decoding_layer_train(encoder_state, dec_cell, dec_embed_input, target_sequence_length, max_target_sequence_length, output_layer, keep_prob)` function to get the training logits.
# * Use your `decoding_layer_infer(encoder_state, dec_cell, dec_embeddings, start_of_sequence_id, end_of_sequence_id, max_target_sequence_length, vocab_size, output_layer, batch_size, keep_prob)` function to get the inference logits.
#
# Note: You'll need to use [tf.variable_scope](https://www.tensorflow.org/api_docs/python/tf/variable_scope) to share variables between training and inference.

# %%
def decoding_layer(dec_input, encoder_state,
                   target_sequence_length, max_target_sequence_length,
                   rnn_size,
                   num_layers, target_vocab_to_int, target_vocab_size,
                   batch_size, keep_prob, decoding_embedding_size):
    """
    Create decoding layer
    :param dec_input: Decoder input
    :param encoder_state: Encoder state
    :param target_sequence_length: The lengths of each sequence in the target batch
    :param max_target_sequence_length: Maximum length of target sequences
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :param target_vocab_size: Size of target vocabulary
    :param batch_size: The size of the batch
    :param keep_prob: Dropout keep probability
    :param decoding_embedding_size: Decoding embedding size
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    #Implementation:
    ## Build the Decoder Embedding
    dec_embeddings = tf.Variable(tf.random_uniform([target_vocab_size, decoding_embedding_size]))
    dec_embed_input = tf.nn.embedding_lookup(dec_embeddings, dec_input)
    
    ## Build the decoder LSTM cell
    def make_cell(rnn_size):
        lstm = tf.contrib.rnn.LSTMCell(rnn_size)
        dropout = tf.contrib.rnn.DropoutWrapper(cell=lstm, output_keep_prob=keep_prob)
        return dropout
    
    dec_cell=tf.contrib.rnn.MultiRNNCell([make_cell(rnn_size) for _ in range(num_layers)])
    
    ## Dense layer to translate the decoder's output at each time-step
    ## into a choice from the target vocabulary
    output_layer=Dense(target_vocab_size,
                      kernel_initializer=tf.truncated_normal_initializer(mean=0.0, stddev=0.1))
    
    with tf.variable_scope("decode"):
        training_decoder_output=decoding_layer_train(encoder_state, 
                                                     dec_cell, 
                                                     dec_embed_input, 
                                                     target_sequence_length,
                                                     max_target_sequence_length,
                                                     output_layer, keep_prob)
    with tf.variable_scope("decode", reuse=True):
        inference_decoder_output=decoding_layer_infer(encoder_state, 
                                                      dec_cell, 
                                                      dec_embeddings, 
                                                      target_vocab_to_int['<GO>'], 
                                                      target_vocab_to_int['<EOS>'], 
                                                      max_target_sequence_length, 
                                                      target_vocab_size, 
                                                      output_layer, 
                                                      batch_size, keep_prob)
    return training_decoder_output, inference_decoder_output



"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_decoding_layer(decoding_layer)
# Out:
# Tests Passed

# %% [markdown]
# ### Build the Neural Network
# Apply the functions you implemented above to:
#
# - Encode the input using your `encoding_layer(rnn_inputs, rnn_size, num_layers, keep_prob,  source_sequence_length, source_vocab_size, encoding_embedding_size)`.
# - Process target data using your `process_decoder_input(target_data, target_vocab_to_int, batch_size)` function.
# - Decode the encoded input using your `decoding_layer(dec_input, enc_state, target_sequence_length, max_target_sentence_length, rnn_size, num_layers, target_vocab_to_int, target_vocab_size, batch_size, keep_prob, dec_embedding_size)` function.

# %%
def seq2seq_model(input_data, target_data, keep_prob, batch_size,
                  source_sequence_length, target_sequence_length,
                  max_target_sentence_length,
                  source_vocab_size, target_vocab_size,
                  enc_embedding_size, dec_embedding_size,
                  rnn_size, num_layers, target_vocab_to_int):
    """
    Build the Sequence-to-Sequence part of the neural network
    :param input_data: Input placeholder
    :param target_data: Target placeholder
    :param keep_prob: Dropout keep probability placeholder
    :param batch_size: Batch Size
    :param source_sequence_length: Sequence Lengths of source sequences in the batch
    :param target_sequence_length: Sequence Lengths of target sequences in the batch
    :param source_vocab_size: Source vocabulary size
    :param target_vocab_size: Target vocabulary size
    :param enc_embedding_size: Decoder embedding size
    :param dec_embedding_size: Encoder embedding size
    :param rnn_size: RNN Size
    :param num_layers: Number of layers
    :param target_vocab_to_int: Dictionary to go from the target words to an id
    :return: Tuple of (Training BasicDecoderOutput, Inference BasicDecoderOutput)
    """
    # Hook up the encoder & decoder and pass through the decoding layer
    # Implmentation
    ## Pass the input data through the encoder.
    ## Ignore the encoder output, but use the state

    _, encoder_state = encoding_layer(input_data, 
                                      rnn_size,
                                      num_layers,
                                      keep_prob,
                                      source_sequence_length,
                                      source_vocab_size,
                                      enc_embedding_size)
    ## Prepare the target sequences we'll feed the decoder in training mode
    decoder_input = process_decoder_input(target_data,
                                         target_vocab_to_int,
                                         batch_size)
    
    ## Pass encoder state and decoder inputs to the decoder layer and hence 
    ## to the training and inference decoders

    training_decoder_output, inference_decoder_output = decoding_layer(decoder_input,
                                                                       encoder_state,
                                                                       target_sequence_length,
                                                                       max_target_sentence_length,
                                                                       rnn_size,
                                                                       num_layers,
                                                                       target_vocab_to_int,
                                                                       target_vocab_size,
                                                                       batch_size,
                                                                       keep_prob,
                                                                       dec_embedding_size)
    
    
    return training_decoder_output, inference_decoder_output


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_seq2seq_model(seq2seq_model)
# Out:
# Tests Passed

# %% [markdown]
# ## Neural Network Training
# ### Hyperparameters
# Tune the following parameters:
#
# - Set `epochs` to the number of epochs.
# - Set `batch_size` to the batch size.
# - Set `rnn_size` to the size of the RNNs.
# - Set `num_layers` to the number of layers.
# - Set `encoding_embedding_size` to the size of the embedding for the encoder.
# - Set `decoding_embedding_size` to the size of the embedding for the decoder.
# - Set `learning_rate` to the learning rate.
# - Set `keep_probability` to the Dropout keep probability
# - Set `display_step` to state how many steps between each debug output statement

# %%
# Number of Epochs
epochs = 5
# Batch Size
batch_size = 128
# RNN Size
rnn_size = 128
# Number of Layers
num_layers = 2
# Embedding Size
encoding_embedding_size = 200
decoding_embedding_size = 200
# Learning Rate
learning_rate = .001
# Dropout Keep Probability
keep_probability = 0.9
display_step = 10

# %% [markdown]
# ### Build the Graph
# Build the graph using the neural network you implemented.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
save_path = 'checkpoints/dev'
(source_int_text, target_int_text), (source_vocab_to_int, target_vocab_to_int), _ = helper.load_preprocess()
max_target_sentence_length = max([len(sentence) for sentence in source_int_text])

train_graph = tf.Graph()
with train_graph.as_default():
    input_data, targets, lr, keep_prob, target_sequence_length, max_target_sequence_length, source_sequence_length = model_inputs()

    #sequence_length = tf.placeholder_with_default(max_target_sentence_length, None, name='sequence_length')
    input_shape = tf.shape(input_data)

    train_logits, inference_logits = seq2seq_model(tf.reverse(input_data, [-1]),
                                                   targets,
                                                   keep_prob,
                                                   batch_size,
                                                   source_sequence_length,
                                                   target_sequence_length,
                                                   max_target_sequence_length,
                                                   len(source_vocab_to_int),
                                                   len(target_vocab_to_int),
                                                   encoding_embedding_size,
                                                   decoding_embedding_size,
                                                   rnn_size,
                                                   num_layers,
                                                   target_vocab_to_int)


    training_logits = tf.identity(train_logits.rnn_output, name='logits')
    inference_logits = tf.identity(inference_logits.sample_id, name='predictions')

    masks = tf.sequence_mask(target_sequence_length, max_target_sequence_length, dtype=tf.float32, name='masks')

    with tf.name_scope("optimization"):
        # Loss function
        cost = tf.contrib.seq2seq.sequence_loss(
            training_logits,
            targets,
            masks)

        # Optimizer
        optimizer = tf.train.AdamOptimizer(lr)

        # Gradient Clipping
        gradients = optimizer.compute_gradients(cost)
        capped_gradients = [(tf.clip_by_value(grad, -1., 1.), var) for grad, var in gradients if grad is not None]
        train_op = optimizer.apply_gradients(capped_gradients)

# %% [markdown]
# Batch and pad the source and target sequences

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def pad_sentence_batch(sentence_batch, pad_int):
    """Pad sentences with <PAD> so that each sentence of a batch has the same length"""
    max_sentence = max([len(sentence) for sentence in sentence_batch])
    return [sentence + [pad_int] * (max_sentence - len(sentence)) for sentence in sentence_batch]


def get_batches(sources, targets, batch_size, source_pad_int, target_pad_int):
    """Batch targets, sources, and the lengths of their sentences together"""
    for batch_i in range(0, len(sources)//batch_size):
        start_i = batch_i * batch_size

        # Slice the right amount for the batch
        sources_batch = sources[start_i:start_i + batch_size]
        targets_batch = targets[start_i:start_i + batch_size]

        # Pad
        pad_sources_batch = np.array(pad_sentence_batch(sources_batch, source_pad_int))
        pad_targets_batch = np.array(pad_sentence_batch(targets_batch, target_pad_int))

        # Need the lengths for the _lengths parameters
        pad_targets_lengths = []
        for target in pad_targets_batch:
            pad_targets_lengths.append(len(target))

        pad_source_lengths = []
        for source in pad_sources_batch:
            pad_source_lengths.append(len(source))

        yield pad_sources_batch, pad_targets_batch, pad_source_lengths, pad_targets_lengths

# %% [markdown]
# ### Train
# Train the neural network on the preprocessed data. If you have a hard time getting a good loss, check the forms to see if anyone is having the same problem.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
def get_accuracy(target, logits):
    """
    Calculate accuracy
    """
    max_seq = max(target.shape[1], logits.shape[1])
    if max_seq - target.shape[1]:
        target = np.pad(
            target,
            [(0,0),(0,max_seq - target.shape[1])],
            'constant')
    if max_seq - logits.shape[1]:
        logits = np.pad(
            logits,
            [(0,0),(0,max_seq - logits.shape[1])],
            'constant')

    return np.mean(np.equal(target, logits))

# Split data to training and validation sets
train_source = source_int_text[batch_size:]
train_target = target_int_text[batch_size:]
valid_source = source_int_text[:batch_size]
valid_target = target_int_text[:batch_size]
(valid_sources_batch, valid_targets_batch, valid_sources_lengths, valid_targets_lengths ) = next(get_batches(valid_source,
                                                                                                             valid_target,
                                                                                                             batch_size,
                                                                                                             source_vocab_to_int['<PAD>'],
                                                                                                             target_vocab_to_int['<PAD>']))                                                                                                  
with tf.Session(graph=train_graph) as sess:
    sess.run(tf.global_variables_initializer())

    for epoch_i in range(epochs):
        for batch_i, (source_batch, target_batch, sources_lengths, targets_lengths) in enumerate(
                get_batches(train_source, train_target, batch_size,
                            source_vocab_to_int['<PAD>'],
                            target_vocab_to_int['<PAD>'])):

            _, loss = sess.run(
                [train_op, cost],
                {input_data: source_batch,
                 targets: target_batch,
                 lr: learning_rate,
                 target_sequence_length: targets_lengths,
                 source_sequence_length: sources_lengths,
                 keep_prob: keep_probability})


            if batch_i % display_step == 0 and batch_i > 0:


                batch_train_logits = sess.run(
                    inference_logits,
                    {input_data: source_batch,
                     source_sequence_length: sources_lengths,
                     target_sequence_length: targets_lengths,
                     keep_prob: 1.0})


                batch_valid_logits = sess.run(
                    inference_logits,
                    {input_data: valid_sources_batch,
                     source_sequence_length: valid_sources_lengths,
                     target_sequence_length: valid_targets_lengths,
                     keep_prob: 1.0})

                train_acc = get_accuracy(target_batch, batch_train_logits)

                valid_acc = get_accuracy(valid_targets_batch, batch_valid_logits)

                print('Epoch {:>3} Batch {:>4}/{} - Train Accuracy: {:>6.4f}, Validation Accuracy: {:>6.4f}, Loss: {:>6.4f}'
                      .format(epoch_i, batch_i, len(source_int_text) // batch_size, train_acc, valid_acc, loss))

    # Save Model
    saver = tf.train.Saver()
    saver.save(sess, save_path)
    print('Model Trained and Saved')
# Out:
# Epoch   0 Batch   10/1077 - Train Accuracy: 0.2340, Validation Accuracy: 0.3352, Loss: 4.3703
# Epoch   0 Batch   20/1077 - Train Accuracy: 0.2707, Validation Accuracy: 0.3366, Loss: 3.5052
# Epoch   0 Batch   30/1077 - Train Accuracy: 0.3172, Validation Accuracy: 0.3871, Loss: 3.1605
# Epoch   0 Batch   40/1077 - Train Accuracy: 0.3750, Validation Accuracy: 0.4318, Loss: 2.9474
# Epoch   0 Batch   50/1077 - Train Accuracy: 0.3715, Validation Accuracy: 0.4393, Loss: 2.8587
# Epoch   0 Batch   60/1077 - Train Accuracy: 0.4226, Validation Accuracy: 0.4513, Loss: 2.6294
# Epoch   0 Batch   70/1077 - Train Accuracy: 0.3997, Validation Accuracy: 0.4716, Loss: 2.7010
# Epoch   0 Batch   80/1077 - Train Accuracy: 0.4074, Validation Accuracy: 0.4737, Loss: 2.4903
# Epoch   0 Batch   90/1077 - Train Accuracy: 0.4488, Validation Accuracy: 0.5004, Loss: 2.4901
# Epoch   0 Batch  100/1077 - Train Accuracy: 0.4348, Validation Accuracy: 0.4933, Loss: 2.3483
# Epoch   0 Batch  110/1077 - Train Accuracy: 0.4664, Validation Accuracy: 0.5007, Loss: 2.1843
# Epoch   0 Batch  120/1077 - Train Accuracy: 0.4465, Validation Accuracy: 0.5089, Loss: 2.1697
# Epoch   0 Batch  130/1077 - Train Accuracy: 0.4360, Validation Accuracy: 0.4915, Loss: 1.9594
# Epoch   0 Batch  140/1077 - Train Accuracy: 0.4276, Validation Accuracy: 0.5082, Loss: 2.1013
# Epoch   0 Batch  150/1077 - Train Accuracy: 0.4565, Validation Accuracy: 0.4737, Loss: 1.8013
# Epoch   0 Batch  160/1077 - Train Accuracy: 0.4434, Validation Accuracy: 0.4840, Loss: 1.8131
# Epoch   0 Batch  170/1077 - Train Accuracy: 0.4266, Validation Accuracy: 0.5028, Loss: 1.8179
# Epoch   0 Batch  180/1077 - Train Accuracy: 0.4273, Validation Accuracy: 0.4766, Loss: 1.6964
# Epoch   0 Batch  190/1077 - Train Accuracy: 0.4383, Validation Accuracy: 0.4819, Loss: 1.6345
# Epoch   0 Batch  200/1077 - Train Accuracy: 0.4031, Validation Accuracy: 0.4581, Loss: 1.6315
# Epoch   0 Batch  210/1077 - Train Accuracy: 0.4550, Validation Accuracy: 0.4872, Loss: 1.5605
# Epoch   0 Batch  220/1077 - Train Accuracy: 0.4420, Validation Accuracy: 0.4929, Loss: 1.5375
# Epoch   0 Batch  230/1077 - Train Accuracy: 0.4572, Validation Accuracy: 0.4545, Loss: 1.3722
# Epoch   0 Batch  240/1077 - Train Accuracy: 0.4648, Validation Accuracy: 0.4904, Loss: 1.3923
# Epoch   0 Batch  250/1077 - Train Accuracy: 0.4535, Validation Accuracy: 0.4858, Loss: 1.2652
# Epoch   0 Batch  260/1077 - Train Accuracy: 0.5082, Validation Accuracy: 0.5206, Loss: 1.2672
# Epoch   0 Batch  270/1077 - Train Accuracy: 0.4637, Validation Accuracy: 0.5316, Loss: 1.3630
# Epoch   0 Batch  280/1077 - Train Accuracy: 0.5012, Validation Accuracy: 0.5075, Loss: 1.2714
# Epoch   0 Batch  290/1077 - Train Accuracy: 0.4719, Validation Accuracy: 0.4982, Loss: 1.2494
# Epoch   0 Batch  300/1077 - Train Accuracy: 0.4519, Validation Accuracy: 0.5202, Loss: 1.2604
# Epoch   0 Batch  310/1077 - Train Accuracy: 0.4598, Validation Accuracy: 0.5014, Loss: 1.1575
# Epoch   0 Batch  320/1077 - Train Accuracy: 0.5316, Validation Accuracy: 0.5330, Loss: 1.1648
# Epoch   0 Batch  330/1077 - Train Accuracy: 0.5102, Validation Accuracy: 0.5181, Loss: 1.1145
# Epoch   0 Batch  340/1077 - Train Accuracy: 0.4790, Validation Accuracy: 0.5309, Loss: 1.1092
# Epoch   0 Batch  350/1077 - Train Accuracy: 0.4555, Validation Accuracy: 0.5206, Loss: 1.1217
# Epoch   0 Batch  360/1077 - Train Accuracy: 0.5203, Validation Accuracy: 0.5437, Loss: 1.0294
# Epoch   0 Batch  370/1077 - Train Accuracy: 0.5179, Validation Accuracy: 0.5558, Loss: 0.9668
# Epoch   0 Batch  380/1077 - Train Accuracy: 0.5309, Validation Accuracy: 0.5771, Loss: 0.9652
# Epoch   0 Batch  390/1077 - Train Accuracy: 0.5230, Validation Accuracy: 0.5824, Loss: 1.0142
# Epoch   0 Batch  400/1077 - Train Accuracy: 0.5371, Validation Accuracy: 0.5746, Loss: 0.9397
# Epoch   0 Batch  410/1077 - Train Accuracy: 0.5193, Validation Accuracy: 0.5810, Loss: 0.9583
# Epoch   0 Batch  420/1077 - Train Accuracy: 0.5223, Validation Accuracy: 0.5888, Loss: 0.9063
# Epoch   0 Batch  430/1077 - Train Accuracy: 0.5270, Validation Accuracy: 0.5842, Loss: 0.8878
# Epoch   0 Batch  440/1077 - Train Accuracy: 0.5445, Validation Accuracy: 0.5859, Loss: 0.9184
# Epoch   0 Batch  450/1077 - Train Accuracy: 0.5484, Validation Accuracy: 0.5827, Loss: 0.8547
# Epoch   0 Batch  460/1077 - Train Accuracy: 0.5336, Validation Accuracy: 0.5969, Loss: 0.8645
# Epoch   0 Batch  470/1077 - Train Accuracy: 0.5461, Validation Accuracy: 0.6080, Loss: 0.8647
# Epoch   0 Batch  480/1077 - Train Accuracy: 0.5876, Validation Accuracy: 0.6090, Loss: 0.8335
# Epoch   0 Batch  490/1077 - Train Accuracy: 0.5633, Validation Accuracy: 0.6154, Loss: 0.8127
# Epoch   0 Batch  500/1077 - Train Accuracy: 0.6012, Validation Accuracy: 0.6246, Loss: 0.7918
# Epoch   0 Batch  510/1077 - Train Accuracy: 0.6148, Validation Accuracy: 0.6133, Loss: 0.7751
# Epoch   0 Batch  520/1077 - Train Accuracy: 0.6205, Validation Accuracy: 0.6243, Loss: 0.7319
# Epoch   0 Batch  530/1077 - Train Accuracy: 0.5918, Validation Accuracy: 0.6271, Loss: 0.7712
# Epoch   0 Batch  540/1077 - Train Accuracy: 0.5777, Validation Accuracy: 0.6122, Loss: 0.7244
# Epoch   0 Batch  550/1077 - Train Accuracy: 0.5680, Validation Accuracy: 0.6183, Loss: 0.7706
# Epoch   0 Batch  560/1077 - Train Accuracy: 0.6191, Validation Accuracy: 0.6364, Loss: 0.7099
# Epoch   0 Batch  570/1077 - Train Accuracy: 0.6012, Validation Accuracy: 0.6374, Loss: 0.7433
# Epoch   0 Batch  580/1077 - Train Accuracy: 0.6403, Validation Accuracy: 0.6232, Loss: 0.6597
# Epoch   0 Batch  590/1077 - Train Accuracy: 0.5954, Validation Accuracy: 0.6143, Loss: 0.7167
# Epoch   0 Batch  600/1077 - Train Accuracy: 0.6209, Validation Accuracy: 0.6229, Loss: 0.6612
# Epoch   0 Batch  610/1077 - Train Accuracy: 0.5958, Validation Accuracy: 0.6122, Loss: 0.7276
# Epoch   0 Batch  620/1077 - Train Accuracy: 0.6152, Validation Accuracy: 0.6204, Loss: 0.6726
# Epoch   0 Batch  630/1077 - Train Accuracy: 0.6070, Validation Accuracy: 0.6357, Loss: 0.6747
# Epoch   0 Batch  640/1077 - Train Accuracy: 0.6202, Validation Accuracy: 0.6420, Loss: 0.6472
# Epoch   0 Batch  650/1077 - Train Accuracy: 0.6008, Validation Accuracy: 0.6183, Loss: 0.6757
# Epoch   0 Batch  660/1077 - Train Accuracy: 0.6371, Validation Accuracy: 0.6243, Loss: 0.6685
# Epoch   0 Batch  670/1077 - Train Accuracy: 0.6811, Validation Accuracy: 0.6296, Loss: 0.6005
# Epoch   0 Batch  680/1077 - Train Accuracy: 0.6499, Validation Accuracy: 0.6112, Loss: 0.6241
# Epoch   0 Batch  690/1077 - Train Accuracy: 0.6375, Validation Accuracy: 0.6388, Loss: 0.6216
# Epoch   0 Batch  700/1077 - Train Accuracy: 0.5934, Validation Accuracy: 0.6072, Loss: 0.6094
# Epoch   0 Batch  710/1077 - Train Accuracy: 0.6098, Validation Accuracy: 0.6147, Loss: 0.6210
# Epoch   0 Batch  720/1077 - Train Accuracy: 0.6176, Validation Accuracy: 0.6243, Loss: 0.6659
# Epoch   0 Batch  730/1077 - Train Accuracy: 0.6516, Validation Accuracy: 0.6385, Loss: 0.6134
# Epoch   0 Batch  740/1077 - Train Accuracy: 0.6215, Validation Accuracy: 0.6175, Loss: 0.5902
# Epoch   0 Batch  750/1077 - Train Accuracy: 0.6363, Validation Accuracy: 0.6417, Loss: 0.5898
# Epoch   0 Batch  760/1077 - Train Accuracy: 0.6301, Validation Accuracy: 0.6428, Loss: 0.5987
# Epoch   0 Batch  770/1077 - Train Accuracy: 0.6458, Validation Accuracy: 0.6303, Loss: 0.5460
# Epoch   0 Batch  780/1077 - Train Accuracy: 0.6148, Validation Accuracy: 0.6435, Loss: 0.5940
# Epoch   0 Batch  790/1077 - Train Accuracy: 0.6004, Validation Accuracy: 0.6317, Loss: 0.5970
# Epoch   0 Batch  800/1077 - Train Accuracy: 0.6496, Validation Accuracy: 0.6477, Loss: 0.5588
# Epoch   0 Batch  810/1077 - Train Accuracy: 0.6596, Validation Accuracy: 0.6442, Loss: 0.5294
# Epoch   0 Batch  820/1077 - Train Accuracy: 0.6133, Validation Accuracy: 0.6538, Loss: 0.5789
# Epoch   0 Batch  830/1077 - Train Accuracy: 0.6402, Validation Accuracy: 0.6538, Loss: 0.5357
# Epoch   0 Batch  840/1077 - Train Accuracy: 0.6551, Validation Accuracy: 0.6275, Loss: 0.5228
# Epoch   0 Batch  850/1077 - Train Accuracy: 0.5997, Validation Accuracy: 0.6548, Loss: 0.5673
# Epoch   0 Batch  860/1077 - Train Accuracy: 0.6536, Validation Accuracy: 0.6587, Loss: 0.5199
# Epoch   0 Batch  870/1077 - Train Accuracy: 0.6394, Validation Accuracy: 0.6680, Loss: 0.5545
# Epoch   0 Batch  880/1077 - Train Accuracy: 0.7094, Validation Accuracy: 0.6509, Loss: 0.5074
# Epoch   0 Batch  890/1077 - Train Accuracy: 0.7139, Validation Accuracy: 0.6552, Loss: 0.4930
# Epoch   0 Batch  900/1077 - Train Accuracy: 0.6930, Validation Accuracy: 0.6658, Loss: 0.5228
# Epoch   0 Batch  910/1077 - Train Accuracy: 0.6525, Validation Accuracy: 0.6474, Loss: 0.4919
# Epoch   0 Batch  920/1077 - Train Accuracy: 0.6742, Validation Accuracy: 0.6850, Loss: 0.5043
# Epoch   0 Batch  930/1077 - Train Accuracy: 0.7082, Validation Accuracy: 0.6829, Loss: 0.4875
# Epoch   0 Batch  940/1077 - Train Accuracy: 0.6785, Validation Accuracy: 0.6562, Loss: 0.4909
# Epoch   0 Batch  950/1077 - Train Accuracy: 0.6808, Validation Accuracy: 0.6793, Loss: 0.4711
# Epoch   0 Batch  960/1077 - Train Accuracy: 0.7031, Validation Accuracy: 0.6871, Loss: 0.4617
# Epoch   0 Batch  970/1077 - Train Accuracy: 0.7109, Validation Accuracy: 0.6445, Loss: 0.4902
# Epoch   0 Batch  980/1077 - Train Accuracy: 0.6930, Validation Accuracy: 0.7077, Loss: 0.4855
# Epoch   0 Batch  990/1077 - Train Accuracy: 0.6686, Validation Accuracy: 0.7085, Loss: 0.4971
# Epoch   0 Batch 1000/1077 - Train Accuracy: 0.7426, Validation Accuracy: 0.6882, Loss: 0.4346
# Epoch   0 Batch 1010/1077 - Train Accuracy: 0.6906, Validation Accuracy: 0.6928, Loss: 0.4616
# Epoch   0 Batch 1020/1077 - Train Accuracy: 0.7117, Validation Accuracy: 0.7124, Loss: 0.4375
# Epoch   0 Batch 1030/1077 - Train Accuracy: 0.6965, Validation Accuracy: 0.7013, Loss: 0.4638
# Epoch   0 Batch 1040/1077 - Train Accuracy: 0.6986, Validation Accuracy: 0.7106, Loss: 0.4706
# Epoch   0 Batch 1050/1077 - Train Accuracy: 0.6836, Validation Accuracy: 0.7042, Loss: 0.4340
# Epoch   0 Batch 1060/1077 - Train Accuracy: 0.6898, Validation Accuracy: 0.6907, Loss: 0.4099
# Epoch   0 Batch 1070/1077 - Train Accuracy: 0.7027, Validation Accuracy: 0.7266, Loss: 0.4385
# Epoch   1 Batch   10/1077 - Train Accuracy: 0.7438, Validation Accuracy: 0.7248, Loss: 0.4369
# Epoch   1 Batch   20/1077 - Train Accuracy: 0.7129, Validation Accuracy: 0.7305, Loss: 0.3868
# Epoch   1 Batch   30/1077 - Train Accuracy: 0.7137, Validation Accuracy: 0.7262, Loss: 0.4139
# Epoch   1 Batch   40/1077 - Train Accuracy: 0.7566, Validation Accuracy: 0.7393, Loss: 0.4031
# Epoch   1 Batch   50/1077 - Train Accuracy: 0.7211, Validation Accuracy: 0.7216, Loss: 0.4014
# Epoch   1 Batch   60/1077 - Train Accuracy: 0.7638, Validation Accuracy: 0.7425, Loss: 0.3768
# Epoch   1 Batch   70/1077 - Train Accuracy: 0.7237, Validation Accuracy: 0.7440, Loss: 0.4138
# Epoch   1 Batch   80/1077 - Train Accuracy: 0.7273, Validation Accuracy: 0.7404, Loss: 0.3930
# Epoch   1 Batch   90/1077 - Train Accuracy: 0.7457, Validation Accuracy: 0.7475, Loss: 0.4093
# Epoch   1 Batch  100/1077 - Train Accuracy: 0.7320, Validation Accuracy: 0.7415, Loss: 0.3893
# Epoch   1 Batch  110/1077 - Train Accuracy: 0.7633, Validation Accuracy: 0.7504, Loss: 0.3568
# Epoch   1 Batch  120/1077 - Train Accuracy: 0.7348, Validation Accuracy: 0.7475, Loss: 0.3893
# Epoch   1 Batch  130/1077 - Train Accuracy: 0.7786, Validation Accuracy: 0.7493, Loss: 0.3380
# Epoch   1 Batch  140/1077 - Train Accuracy: 0.7582, Validation Accuracy: 0.7571, Loss: 0.3731
# Epoch   1 Batch  150/1077 - Train Accuracy: 0.7556, Validation Accuracy: 0.7401, Loss: 0.3563
# Epoch   1 Batch  160/1077 - Train Accuracy: 0.7711, Validation Accuracy: 0.7436, Loss: 0.3502
# Epoch   1 Batch  170/1077 - Train Accuracy: 0.7715, Validation Accuracy: 0.7511, Loss: 0.3714
# Epoch   1 Batch  180/1077 - Train Accuracy: 0.7488, Validation Accuracy: 0.7592, Loss: 0.3360
# Epoch   1 Batch  190/1077 - Train Accuracy: 0.8109, Validation Accuracy: 0.7411, Loss: 0.3369
# Epoch   1 Batch  200/1077 - Train Accuracy: 0.7680, Validation Accuracy: 0.7749, Loss: 0.3588
# Epoch   1 Batch  210/1077 - Train Accuracy: 0.7857, Validation Accuracy: 0.7720, Loss: 0.3331
# Epoch   1 Batch  220/1077 - Train Accuracy: 0.8109, Validation Accuracy: 0.7837, Loss: 0.3307
# Epoch   1 Batch  230/1077 - Train Accuracy: 0.7868, Validation Accuracy: 0.7702, Loss: 0.3189
# Epoch   1 Batch  240/1077 - Train Accuracy: 0.8266, Validation Accuracy: 0.7660, Loss: 0.3053
# Epoch   1 Batch  250/1077 - Train Accuracy: 0.8029, Validation Accuracy: 0.7852, Loss: 0.2971
# Epoch   1 Batch  260/1077 - Train Accuracy: 0.8147, Validation Accuracy: 0.7798, Loss: 0.2895
# Epoch   1 Batch  270/1077 - Train Accuracy: 0.7551, Validation Accuracy: 0.7912, Loss: 0.3353
# Epoch   1 Batch  280/1077 - Train Accuracy: 0.7812, Validation Accuracy: 0.7884, Loss: 0.3337
# Epoch   1 Batch  290/1077 - Train Accuracy: 0.7738, Validation Accuracy: 0.7823, Loss: 0.3306
# Epoch   1 Batch  300/1077 - Train Accuracy: 0.8326, Validation Accuracy: 0.7887, Loss: 0.2983
# Epoch   1 Batch  310/1077 - Train Accuracy: 0.8184, Validation Accuracy: 0.7944, Loss: 0.3008
# Epoch   1 Batch  320/1077 - Train Accuracy: 0.8055, Validation Accuracy: 0.7947, Loss: 0.3045
# Epoch   1 Batch  330/1077 - Train Accuracy: 0.8250, Validation Accuracy: 0.7809, Loss: 0.2994
# Epoch   1 Batch  340/1077 - Train Accuracy: 0.8429, Validation Accuracy: 0.7990, Loss: 0.2866
# Epoch   1 Batch  350/1077 - Train Accuracy: 0.8109, Validation Accuracy: 0.8015, Loss: 0.3066
# Epoch   1 Batch  360/1077 - Train Accuracy: 0.8309, Validation Accuracy: 0.8008, Loss: 0.2754
# Epoch   1 Batch  370/1077 - Train Accuracy: 0.8512, Validation Accuracy: 0.7947, Loss: 0.2680
# Epoch   1 Batch  380/1077 - Train Accuracy: 0.8148, Validation Accuracy: 0.8047, Loss: 0.2675
# Epoch   1 Batch  390/1077 - Train Accuracy: 0.7918, Validation Accuracy: 0.7923, Loss: 0.2826
# Epoch   1 Batch  400/1077 - Train Accuracy: 0.8520, Validation Accuracy: 0.8107, Loss: 0.2725
# Epoch   1 Batch  410/1077 - Train Accuracy: 0.8220, Validation Accuracy: 0.8089, Loss: 0.2649
# Epoch   1 Batch  420/1077 - Train Accuracy: 0.8770, Validation Accuracy: 0.8175, Loss: 0.2399
# Epoch   1 Batch  430/1077 - Train Accuracy: 0.8418, Validation Accuracy: 0.8185, Loss: 0.2361
# Epoch   1 Batch  440/1077 - Train Accuracy: 0.8410, Validation Accuracy: 0.8079, Loss: 0.2602
# Epoch   1 Batch  450/1077 - Train Accuracy: 0.8438, Validation Accuracy: 0.8178, Loss: 0.2474
# Epoch   1 Batch  460/1077 - Train Accuracy: 0.8461, Validation Accuracy: 0.8200, Loss: 0.2515
# Epoch   1 Batch  470/1077 - Train Accuracy: 0.8326, Validation Accuracy: 0.8288, Loss: 0.2631
# Epoch   1 Batch  480/1077 - Train Accuracy: 0.8742, Validation Accuracy: 0.8335, Loss: 0.2461
# Epoch   1 Batch  490/1077 - Train Accuracy: 0.8336, Validation Accuracy: 0.8033, Loss: 0.2415
# Epoch   1 Batch  500/1077 - Train Accuracy: 0.8645, Validation Accuracy: 0.8274, Loss: 0.2197
# Epoch   1 Batch  510/1077 - Train Accuracy: 0.8500, Validation Accuracy: 0.8249, Loss: 0.2204
# Epoch   1 Batch  520/1077 - Train Accuracy: 0.8739, Validation Accuracy: 0.8153, Loss: 0.2110
# Epoch   1 Batch  530/1077 - Train Accuracy: 0.8582, Validation Accuracy: 0.8168, Loss: 0.2203
# Epoch   1 Batch  540/1077 - Train Accuracy: 0.8738, Validation Accuracy: 0.8505, Loss: 0.1949
# Epoch   1 Batch  550/1077 - Train Accuracy: 0.8289, Validation Accuracy: 0.8335, Loss: 0.2321
# Epoch   1 Batch  560/1077 - Train Accuracy: 0.8711, Validation Accuracy: 0.8164, Loss: 0.2027
# Epoch   1 Batch  570/1077 - Train Accuracy: 0.8614, Validation Accuracy: 0.8214, Loss: 0.2228
# Epoch   1 Batch  580/1077 - Train Accuracy: 0.8690, Validation Accuracy: 0.8203, Loss: 0.1899
# Epoch   1 Batch  590/1077 - Train Accuracy: 0.8668, Validation Accuracy: 0.8192, Loss: 0.2163
# Epoch   1 Batch  600/1077 - Train Accuracy: 0.8642, Validation Accuracy: 0.8384, Loss: 0.1969
# Epoch   1 Batch  610/1077 - Train Accuracy: 0.8623, Validation Accuracy: 0.8366, Loss: 0.2072
# Epoch   1 Batch  620/1077 - Train Accuracy: 0.8840, Validation Accuracy: 0.8299, Loss: 0.1817
# Epoch   1 Batch  630/1077 - Train Accuracy: 0.8660, Validation Accuracy: 0.8363, Loss: 0.1883
# Epoch   1 Batch  640/1077 - Train Accuracy: 0.8668, Validation Accuracy: 0.8345, Loss: 0.1806
# Epoch   1 Batch  650/1077 - Train Accuracy: 0.8895, Validation Accuracy: 0.8434, Loss: 0.1918
# Epoch   1 Batch  660/1077 - Train Accuracy: 0.8320, Validation Accuracy: 0.8338, Loss: 0.1940
# Epoch   1 Batch  670/1077 - Train Accuracy: 0.8924, Validation Accuracy: 0.8331, Loss: 0.1818
# Epoch   1 Batch  680/1077 - Train Accuracy: 0.8635, Validation Accuracy: 0.8278, Loss: 0.1801
# Epoch   1 Batch  690/1077 - Train Accuracy: 0.8727, Validation Accuracy: 0.8281, Loss: 0.1710
# Epoch   1 Batch  700/1077 - Train Accuracy: 0.8797, Validation Accuracy: 0.8391, Loss: 0.1591
# Epoch   1 Batch  710/1077 - Train Accuracy: 0.8734, Validation Accuracy: 0.8430, Loss: 0.1651
# Epoch   1 Batch  720/1077 - Train Accuracy: 0.8836, Validation Accuracy: 0.8643, Loss: 0.1887
# Epoch   1 Batch  730/1077 - Train Accuracy: 0.8902, Validation Accuracy: 0.8544, Loss: 0.1778
# Epoch   1 Batch  740/1077 - Train Accuracy: 0.8766, Validation Accuracy: 0.8629, Loss: 0.1518
# Epoch   1 Batch  750/1077 - Train Accuracy: 0.8727, Validation Accuracy: 0.8406, Loss: 0.1610
# Epoch   1 Batch  760/1077 - Train Accuracy: 0.9016, Validation Accuracy: 0.8810, Loss: 0.1675
# Epoch   1 Batch  770/1077 - Train Accuracy: 0.8717, Validation Accuracy: 0.8803, Loss: 0.1502
# Epoch   1 Batch  780/1077 - Train Accuracy: 0.8371, Validation Accuracy: 0.8580, Loss: 0.1839
# Epoch   1 Batch  790/1077 - Train Accuracy: 0.8094, Validation Accuracy: 0.8704, Loss: 0.1635
# Epoch   1 Batch  800/1077 - Train Accuracy: 0.8566, Validation Accuracy: 0.8729, Loss: 0.1516
# Epoch   1 Batch  810/1077 - Train Accuracy: 0.8798, Validation Accuracy: 0.8526, Loss: 0.1365
# Epoch   1 Batch  820/1077 - Train Accuracy: 0.8797, Validation Accuracy: 0.8704, Loss: 0.1602
# Epoch   1 Batch  830/1077 - Train Accuracy: 0.8488, Validation Accuracy: 0.8711, Loss: 0.1440
# Epoch   1 Batch  840/1077 - Train Accuracy: 0.8938, Validation Accuracy: 0.8679, Loss: 0.1301
# Epoch   1 Batch  850/1077 - Train Accuracy: 0.8839, Validation Accuracy: 0.8746, Loss: 0.1676
# Epoch   1 Batch  860/1077 - Train Accuracy: 0.8705, Validation Accuracy: 0.8771, Loss: 0.1497
# Epoch   1 Batch  870/1077 - Train Accuracy: 0.8318, Validation Accuracy: 0.8675, Loss: 0.1502
# Epoch   1 Batch  880/1077 - Train Accuracy: 0.8992, Validation Accuracy: 0.8732, Loss: 0.1436
# Epoch   1 Batch  890/1077 - Train Accuracy: 0.9170, Validation Accuracy: 0.8697, Loss: 0.1395
# Epoch   1 Batch  900/1077 - Train Accuracy: 0.9187, Validation Accuracy: 0.8906, Loss: 0.1475
# Epoch   1 Batch  910/1077 - Train Accuracy: 0.8843, Validation Accuracy: 0.8743, Loss: 0.1354
# Epoch   1 Batch  920/1077 - Train Accuracy: 0.9047, Validation Accuracy: 0.8693, Loss: 0.1356
# Epoch   1 Batch  930/1077 - Train Accuracy: 0.9082, Validation Accuracy: 0.8672, Loss: 0.1210
# Epoch   1 Batch  940/1077 - Train Accuracy: 0.8926, Validation Accuracy: 0.8668, Loss: 0.1181
# Epoch   1 Batch  950/1077 - Train Accuracy: 0.9029, Validation Accuracy: 0.8729, Loss: 0.1151
# Epoch   1 Batch  960/1077 - Train Accuracy: 0.9059, Validation Accuracy: 0.8885, Loss: 0.1206
# Epoch   1 Batch  970/1077 - Train Accuracy: 0.9172, Validation Accuracy: 0.8683, Loss: 0.1391
# Epoch   1 Batch  980/1077 - Train Accuracy: 0.8668, Validation Accuracy: 0.8796, Loss: 0.1285
# Epoch   1 Batch  990/1077 - Train Accuracy: 0.9128, Validation Accuracy: 0.8683, Loss: 0.1304
# Epoch   1 Batch 1000/1077 - Train Accuracy: 0.9319, Validation Accuracy: 0.8839, Loss: 0.1176
# Epoch   1 Batch 1010/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.8739, Loss: 0.1147
# Epoch   1 Batch 1020/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.8849, Loss: 0.1071
# Epoch   1 Batch 1030/1077 - Train Accuracy: 0.9055, Validation Accuracy: 0.8729, Loss: 0.1243
# Epoch   1 Batch 1040/1077 - Train Accuracy: 0.8873, Validation Accuracy: 0.8725, Loss: 0.1313
# Epoch   1 Batch 1050/1077 - Train Accuracy: 0.9035, Validation Accuracy: 0.8956, Loss: 0.1115
# Epoch   1 Batch 1060/1077 - Train Accuracy: 0.8957, Validation Accuracy: 0.8896, Loss: 0.1068
# Epoch   1 Batch 1070/1077 - Train Accuracy: 0.9059, Validation Accuracy: 0.8849, Loss: 0.1065
# Epoch   2 Batch   10/1077 - Train Accuracy: 0.9079, Validation Accuracy: 0.9002, Loss: 0.1156
# Epoch   2 Batch   20/1077 - Train Accuracy: 0.9055, Validation Accuracy: 0.9009, Loss: 0.0902
# Epoch   2 Batch   30/1077 - Train Accuracy: 0.9051, Validation Accuracy: 0.9183, Loss: 0.1087
# Epoch   2 Batch   40/1077 - Train Accuracy: 0.9203, Validation Accuracy: 0.8988, Loss: 0.0997
# Epoch   2 Batch   50/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.8956, Loss: 0.1054
# Epoch   2 Batch   60/1077 - Train Accuracy: 0.9286, Validation Accuracy: 0.8874, Loss: 0.0945
# Epoch   2 Batch   70/1077 - Train Accuracy: 0.8877, Validation Accuracy: 0.8828, Loss: 0.1128
# Epoch   2 Batch   80/1077 - Train Accuracy: 0.9301, Validation Accuracy: 0.8807, Loss: 0.0900
# Epoch   2 Batch   90/1077 - Train Accuracy: 0.8852, Validation Accuracy: 0.8903, Loss: 0.1135
# Epoch   2 Batch  100/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.8832, Loss: 0.0935
# Epoch   2 Batch  110/1077 - Train Accuracy: 0.9437, Validation Accuracy: 0.9016, Loss: 0.0801
# Epoch   2 Batch  120/1077 - Train Accuracy: 0.9227, Validation Accuracy: 0.9006, Loss: 0.1080
# Epoch   2 Batch  130/1077 - Train Accuracy: 0.9185, Validation Accuracy: 0.8906, Loss: 0.0882
# Epoch   2 Batch  140/1077 - Train Accuracy: 0.9194, Validation Accuracy: 0.8690, Loss: 0.0949
# Epoch   2 Batch  150/1077 - Train Accuracy: 0.9118, Validation Accuracy: 0.8874, Loss: 0.1036
# Epoch   2 Batch  160/1077 - Train Accuracy: 0.9113, Validation Accuracy: 0.8906, Loss: 0.0925
# Epoch   2 Batch  170/1077 - Train Accuracy: 0.9078, Validation Accuracy: 0.8817, Loss: 0.1025
# Epoch   2 Batch  180/1077 - Train Accuracy: 0.9098, Validation Accuracy: 0.9038, Loss: 0.0860
# Epoch   2 Batch  190/1077 - Train Accuracy: 0.9383, Validation Accuracy: 0.8903, Loss: 0.0804
# Epoch   2 Batch  200/1077 - Train Accuracy: 0.9062, Validation Accuracy: 0.8920, Loss: 0.1011
# Epoch   2 Batch  210/1077 - Train Accuracy: 0.9025, Validation Accuracy: 0.8967, Loss: 0.0956
# Epoch   2 Batch  220/1077 - Train Accuracy: 0.9367, Validation Accuracy: 0.9020, Loss: 0.0932
# Epoch   2 Batch  230/1077 - Train Accuracy: 0.9148, Validation Accuracy: 0.8842, Loss: 0.0842
# Epoch   2 Batch  240/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.8881, Loss: 0.0851
# Epoch   2 Batch  250/1077 - Train Accuracy: 0.9180, Validation Accuracy: 0.8995, Loss: 0.0830
# Epoch   2 Batch  260/1077 - Train Accuracy: 0.9018, Validation Accuracy: 0.9094, Loss: 0.0794
# Epoch   2 Batch  270/1077 - Train Accuracy: 0.8945, Validation Accuracy: 0.9038, Loss: 0.1038
# Epoch   2 Batch  280/1077 - Train Accuracy: 0.8918, Validation Accuracy: 0.9080, Loss: 0.1034
# Epoch   2 Batch  290/1077 - Train Accuracy: 0.9094, Validation Accuracy: 0.9062, Loss: 0.1106
# Epoch   2 Batch  300/1077 - Train Accuracy: 0.9387, Validation Accuracy: 0.9070, Loss: 0.0823
# Epoch   2 Batch  310/1077 - Train Accuracy: 0.9207, Validation Accuracy: 0.9009, Loss: 0.0787
# Epoch   2 Batch  320/1077 - Train Accuracy: 0.9281, Validation Accuracy: 0.9006, Loss: 0.0941
# Epoch   2 Batch  330/1077 - Train Accuracy: 0.9086, Validation Accuracy: 0.9034, Loss: 0.0891
# Epoch   2 Batch  340/1077 - Train Accuracy: 0.9552, Validation Accuracy: 0.8995, Loss: 0.0745
# Epoch   2 Batch  350/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.8800, Loss: 0.0896
# Epoch   2 Batch  360/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9130, Loss: 0.0723
# Epoch   2 Batch  370/1077 - Train Accuracy: 0.9490, Validation Accuracy: 0.9254, Loss: 0.0834
# Epoch   2 Batch  380/1077 - Train Accuracy: 0.9359, Validation Accuracy: 0.9205, Loss: 0.0748
# Epoch   2 Batch  390/1077 - Train Accuracy: 0.9004, Validation Accuracy: 0.9112, Loss: 0.0927
# Epoch   2 Batch  400/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9073, Loss: 0.0958
# Epoch   2 Batch  410/1077 - Train Accuracy: 0.9128, Validation Accuracy: 0.9151, Loss: 0.0888
# Epoch   2 Batch  420/1077 - Train Accuracy: 0.9406, Validation Accuracy: 0.9183, Loss: 0.0625
# Epoch   2 Batch  430/1077 - Train Accuracy: 0.9285, Validation Accuracy: 0.9293, Loss: 0.0712
# Epoch   2 Batch  440/1077 - Train Accuracy: 0.9000, Validation Accuracy: 0.9031, Loss: 0.0967
# Epoch   2 Batch  450/1077 - Train Accuracy: 0.9395, Validation Accuracy: 0.9173, Loss: 0.0759
# Epoch   2 Batch  460/1077 - Train Accuracy: 0.9125, Validation Accuracy: 0.9041, Loss: 0.0803
# Epoch   2 Batch  470/1077 - Train Accuracy: 0.9482, Validation Accuracy: 0.9219, Loss: 0.0712
# Epoch   2 Batch  480/1077 - Train Accuracy: 0.9334, Validation Accuracy: 0.9091, Loss: 0.0749
# Epoch   2 Batch  490/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.8981, Loss: 0.0768
# Epoch   2 Batch  500/1077 - Train Accuracy: 0.9227, Validation Accuracy: 0.9052, Loss: 0.0618
# Epoch   2 Batch  510/1077 - Train Accuracy: 0.9066, Validation Accuracy: 0.9038, Loss: 0.0714
# Epoch   2 Batch  520/1077 - Train Accuracy: 0.9382, Validation Accuracy: 0.8977, Loss: 0.0638
# Epoch   2 Batch  530/1077 - Train Accuracy: 0.9359, Validation Accuracy: 0.9240, Loss: 0.0757
# Epoch   2 Batch  540/1077 - Train Accuracy: 0.9129, Validation Accuracy: 0.9268, Loss: 0.0624
# Epoch   2 Batch  550/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.8942, Loss: 0.0685
# Epoch   2 Batch  560/1077 - Train Accuracy: 0.9133, Validation Accuracy: 0.8970, Loss: 0.0680
# Epoch   2 Batch  570/1077 - Train Accuracy: 0.9211, Validation Accuracy: 0.9016, Loss: 0.0754
# Epoch   2 Batch  580/1077 - Train Accuracy: 0.9568, Validation Accuracy: 0.9077, Loss: 0.0591
# Epoch   2 Batch  590/1077 - Train Accuracy: 0.9194, Validation Accuracy: 0.9105, Loss: 0.0841
# Epoch   2 Batch  600/1077 - Train Accuracy: 0.9241, Validation Accuracy: 0.9016, Loss: 0.0702
# Epoch   2 Batch  610/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9098, Loss: 0.0686
# Epoch   2 Batch  620/1077 - Train Accuracy: 0.9727, Validation Accuracy: 0.9240, Loss: 0.0637
# Epoch   2 Batch  630/1077 - Train Accuracy: 0.9586, Validation Accuracy: 0.9286, Loss: 0.0629
# Epoch   2 Batch  640/1077 - Train Accuracy: 0.9606, Validation Accuracy: 0.9165, Loss: 0.0721
# Epoch   2 Batch  650/1077 - Train Accuracy: 0.9387, Validation Accuracy: 0.9183, Loss: 0.0788
# Epoch   2 Batch  660/1077 - Train Accuracy: 0.9332, Validation Accuracy: 0.9134, Loss: 0.0692
# Epoch   2 Batch  670/1077 - Train Accuracy: 0.9414, Validation Accuracy: 0.9173, Loss: 0.0679
# Epoch   2 Batch  680/1077 - Train Accuracy: 0.9260, Validation Accuracy: 0.9165, Loss: 0.0634
# Epoch   2 Batch  690/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9318, Loss: 0.0717
# Epoch   2 Batch  700/1077 - Train Accuracy: 0.9563, Validation Accuracy: 0.9219, Loss: 0.0559
# Epoch   2 Batch  710/1077 - Train Accuracy: 0.9125, Validation Accuracy: 0.9201, Loss: 0.0599
# Epoch   2 Batch  720/1077 - Train Accuracy: 0.9490, Validation Accuracy: 0.9173, Loss: 0.0726
# Epoch   2 Batch  730/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.9233, Loss: 0.0744
# Epoch   2 Batch  740/1077 - Train Accuracy: 0.9230, Validation Accuracy: 0.9251, Loss: 0.0497
# Epoch   2 Batch  750/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.9087, Loss: 0.0666
# Epoch   2 Batch  760/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.9222, Loss: 0.0653
# Epoch   2 Batch  770/1077 - Train Accuracy: 0.9022, Validation Accuracy: 0.9460, Loss: 0.0590
# Epoch   2 Batch  780/1077 - Train Accuracy: 0.9094, Validation Accuracy: 0.9357, Loss: 0.0783
# Epoch   2 Batch  790/1077 - Train Accuracy: 0.8707, Validation Accuracy: 0.9208, Loss: 0.0730
# Epoch   2 Batch  800/1077 - Train Accuracy: 0.9289, Validation Accuracy: 0.9354, Loss: 0.0620
# Epoch   2 Batch  810/1077 - Train Accuracy: 0.9323, Validation Accuracy: 0.9276, Loss: 0.0509
# Epoch   2 Batch  820/1077 - Train Accuracy: 0.9203, Validation Accuracy: 0.9237, Loss: 0.0581
# Epoch   2 Batch  830/1077 - Train Accuracy: 0.8797, Validation Accuracy: 0.9201, Loss: 0.0658
# Epoch   2 Batch  840/1077 - Train Accuracy: 0.9281, Validation Accuracy: 0.9361, Loss: 0.0540
# Epoch   2 Batch  850/1077 - Train Accuracy: 0.9315, Validation Accuracy: 0.9453, Loss: 0.0821
# Epoch   2 Batch  860/1077 - Train Accuracy: 0.9286, Validation Accuracy: 0.9300, Loss: 0.0627
# Epoch   2 Batch  870/1077 - Train Accuracy: 0.9243, Validation Accuracy: 0.9208, Loss: 0.0578
# Epoch   2 Batch  880/1077 - Train Accuracy: 0.9430, Validation Accuracy: 0.9233, Loss: 0.0617
# Epoch   2 Batch  890/1077 - Train Accuracy: 0.9342, Validation Accuracy: 0.9222, Loss: 0.0599
# Epoch   2 Batch  900/1077 - Train Accuracy: 0.9504, Validation Accuracy: 0.9293, Loss: 0.0634
# Epoch   2 Batch  910/1077 - Train Accuracy: 0.9282, Validation Accuracy: 0.9201, Loss: 0.0594
# Epoch   2 Batch  920/1077 - Train Accuracy: 0.9402, Validation Accuracy: 0.9364, Loss: 0.0573
# Epoch   2 Batch  930/1077 - Train Accuracy: 0.9324, Validation Accuracy: 0.9229, Loss: 0.0456
# Epoch   2 Batch  940/1077 - Train Accuracy: 0.9293, Validation Accuracy: 0.8999, Loss: 0.0558
# Epoch   2 Batch  950/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9293, Loss: 0.0501
# Epoch   2 Batch  960/1077 - Train Accuracy: 0.9431, Validation Accuracy: 0.9350, Loss: 0.0543
# Epoch   2 Batch  970/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9265, Loss: 0.0600
# Epoch   2 Batch  980/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9297, Loss: 0.0614
# Epoch   2 Batch  990/1077 - Train Accuracy: 0.9482, Validation Accuracy: 0.9375, Loss: 0.0627
# Epoch   2 Batch 1000/1077 - Train Accuracy: 0.9561, Validation Accuracy: 0.9254, Loss: 0.0577
# Epoch   2 Batch 1010/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9109, Loss: 0.0539
# Epoch   2 Batch 1020/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9169, Loss: 0.0470
# Epoch   2 Batch 1030/1077 - Train Accuracy: 0.9551, Validation Accuracy: 0.9268, Loss: 0.0534
# Epoch   2 Batch 1040/1077 - Train Accuracy: 0.9482, Validation Accuracy: 0.9379, Loss: 0.0517
# Epoch   2 Batch 1050/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.9442, Loss: 0.0515
# Epoch   2 Batch 1060/1077 - Train Accuracy: 0.9258, Validation Accuracy: 0.9396, Loss: 0.0525
# Epoch   2 Batch 1070/1077 - Train Accuracy: 0.9418, Validation Accuracy: 0.9379, Loss: 0.0490
# Epoch   3 Batch   10/1077 - Train Accuracy: 0.9400, Validation Accuracy: 0.9098, Loss: 0.0643
# Epoch   3 Batch   20/1077 - Train Accuracy: 0.9117, Validation Accuracy: 0.9233, Loss: 0.0454
# Epoch   3 Batch   30/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9325, Loss: 0.0481
# Epoch   3 Batch   40/1077 - Train Accuracy: 0.9703, Validation Accuracy: 0.9347, Loss: 0.0475
# Epoch   3 Batch   50/1077 - Train Accuracy: 0.9566, Validation Accuracy: 0.9304, Loss: 0.0495
# Epoch   3 Batch   60/1077 - Train Accuracy: 0.9360, Validation Accuracy: 0.9134, Loss: 0.0473
# Epoch   3 Batch   70/1077 - Train Accuracy: 0.9215, Validation Accuracy: 0.9332, Loss: 0.0528
# Epoch   3 Batch   80/1077 - Train Accuracy: 0.9578, Validation Accuracy: 0.9318, Loss: 0.0407
# Epoch   3 Batch   90/1077 - Train Accuracy: 0.9203, Validation Accuracy: 0.9464, Loss: 0.0552
# Epoch   3 Batch  100/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9379, Loss: 0.0469
# Epoch   3 Batch  110/1077 - Train Accuracy: 0.9629, Validation Accuracy: 0.9283, Loss: 0.0378
# Epoch   3 Batch  120/1077 - Train Accuracy: 0.9484, Validation Accuracy: 0.9297, Loss: 0.0623
# Epoch   3 Batch  130/1077 - Train Accuracy: 0.9583, Validation Accuracy: 0.9041, Loss: 0.0481
# Epoch   3 Batch  140/1077 - Train Accuracy: 0.9494, Validation Accuracy: 0.9311, Loss: 0.0460
# Epoch   3 Batch  150/1077 - Train Accuracy: 0.9282, Validation Accuracy: 0.9233, Loss: 0.0520
# Epoch   3 Batch  160/1077 - Train Accuracy: 0.9414, Validation Accuracy: 0.9368, Loss: 0.0457
# Epoch   3 Batch  170/1077 - Train Accuracy: 0.9414, Validation Accuracy: 0.9393, Loss: 0.0549
# Epoch   3 Batch  180/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.9371, Loss: 0.0473
# Epoch   3 Batch  190/1077 - Train Accuracy: 0.9574, Validation Accuracy: 0.9261, Loss: 0.0448
# Epoch   3 Batch  200/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.9382, Loss: 0.0536
# Epoch   3 Batch  210/1077 - Train Accuracy: 0.9394, Validation Accuracy: 0.9272, Loss: 0.0548
# Epoch   3 Batch  220/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9414, Loss: 0.0512
# Epoch   3 Batch  230/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9222, Loss: 0.0393
# Epoch   3 Batch  240/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9322, Loss: 0.0419
# Epoch   3 Batch  250/1077 - Train Accuracy: 0.9439, Validation Accuracy: 0.9276, Loss: 0.0506
# Epoch   3 Batch  260/1077 - Train Accuracy: 0.9412, Validation Accuracy: 0.9432, Loss: 0.0404
# Epoch   3 Batch  270/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9304, Loss: 0.0576
# Epoch   3 Batch  280/1077 - Train Accuracy: 0.9309, Validation Accuracy: 0.9421, Loss: 0.0574
# Epoch   3 Batch  290/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9318, Loss: 0.0664
# Epoch   3 Batch  300/1077 - Train Accuracy: 0.9622, Validation Accuracy: 0.9265, Loss: 0.0425
# Epoch   3 Batch  310/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9073, Loss: 0.0468
# Epoch   3 Batch  320/1077 - Train Accuracy: 0.9523, Validation Accuracy: 0.9144, Loss: 0.0567
# Epoch   3 Batch  330/1077 - Train Accuracy: 0.9266, Validation Accuracy: 0.9450, Loss: 0.0486
# Epoch   3 Batch  340/1077 - Train Accuracy: 0.9642, Validation Accuracy: 0.9467, Loss: 0.0386
# Epoch   3 Batch  350/1077 - Train Accuracy: 0.9426, Validation Accuracy: 0.9382, Loss: 0.0494
# Epoch   3 Batch  360/1077 - Train Accuracy: 0.9602, Validation Accuracy: 0.9421, Loss: 0.0360
# Epoch   3 Batch  370/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9414, Loss: 0.0451
# Epoch   3 Batch  380/1077 - Train Accuracy: 0.9566, Validation Accuracy: 0.9329, Loss: 0.0423
# Epoch   3 Batch  390/1077 - Train Accuracy: 0.8996, Validation Accuracy: 0.9347, Loss: 0.0562
# Epoch   3 Batch  400/1077 - Train Accuracy: 0.9348, Validation Accuracy: 0.9293, Loss: 0.0557
# Epoch   3 Batch  410/1077 - Train Accuracy: 0.9285, Validation Accuracy: 0.9439, Loss: 0.0563
# Epoch   3 Batch  420/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9403, Loss: 0.0314
# Epoch   3 Batch  430/1077 - Train Accuracy: 0.9555, Validation Accuracy: 0.9379, Loss: 0.0400
# Epoch   3 Batch  440/1077 - Train Accuracy: 0.9398, Validation Accuracy: 0.9183, Loss: 0.0494
# Epoch   3 Batch  450/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9205, Loss: 0.0455
# Epoch   3 Batch  460/1077 - Train Accuracy: 0.9422, Validation Accuracy: 0.9087, Loss: 0.0504
# Epoch   3 Batch  470/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9428, Loss: 0.0405
# Epoch   3 Batch  480/1077 - Train Accuracy: 0.9511, Validation Accuracy: 0.9283, Loss: 0.0482
# Epoch   3 Batch  490/1077 - Train Accuracy: 0.9332, Validation Accuracy: 0.9361, Loss: 0.0434
# Epoch   3 Batch  500/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9329, Loss: 0.0360
# Epoch   3 Batch  510/1077 - Train Accuracy: 0.9320, Validation Accuracy: 0.9329, Loss: 0.0454
# Epoch   3 Batch  520/1077 - Train Accuracy: 0.9769, Validation Accuracy: 0.9393, Loss: 0.0355
# Epoch   3 Batch  530/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9361, Loss: 0.0477
# Epoch   3 Batch  540/1077 - Train Accuracy: 0.9566, Validation Accuracy: 0.9464, Loss: 0.0371
# Epoch   3 Batch  550/1077 - Train Accuracy: 0.9344, Validation Accuracy: 0.9489, Loss: 0.0400
# Epoch   3 Batch  560/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9457, Loss: 0.0391
# Epoch   3 Batch  570/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.9354, Loss: 0.0490
# Epoch   3 Batch  580/1077 - Train Accuracy: 0.9658, Validation Accuracy: 0.9411, Loss: 0.0316
# Epoch   3 Batch  590/1077 - Train Accuracy: 0.9359, Validation Accuracy: 0.9428, Loss: 0.0517
# Epoch   3 Batch  600/1077 - Train Accuracy: 0.9479, Validation Accuracy: 0.9574, Loss: 0.0459
# Epoch   3 Batch  610/1077 - Train Accuracy: 0.9465, Validation Accuracy: 0.9425, Loss: 0.0524
# Epoch   3 Batch  620/1077 - Train Accuracy: 0.9676, Validation Accuracy: 0.9574, Loss: 0.0400
# Epoch   3 Batch  630/1077 - Train Accuracy: 0.9684, Validation Accuracy: 0.9545, Loss: 0.0464
# Epoch   3 Batch  640/1077 - Train Accuracy: 0.9505, Validation Accuracy: 0.9517, Loss: 0.0387
# Epoch   3 Batch  650/1077 - Train Accuracy: 0.9504, Validation Accuracy: 0.9379, Loss: 0.0461
# Epoch   3 Batch  660/1077 - Train Accuracy: 0.9555, Validation Accuracy: 0.9435, Loss: 0.0418
# Epoch   3 Batch  670/1077 - Train Accuracy: 0.9414, Validation Accuracy: 0.9482, Loss: 0.0407
# Epoch   3 Batch  680/1077 - Train Accuracy: 0.9375, Validation Accuracy: 0.9350, Loss: 0.0410
# Epoch   3 Batch  690/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.9396, Loss: 0.0501
# Epoch   3 Batch  700/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9453, Loss: 0.0378
# Epoch   3 Batch  710/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9244, Loss: 0.0403
# Epoch   3 Batch  720/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9631, Loss: 0.0466
# Epoch   3 Batch  730/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9602, Loss: 0.0483
# Epoch   3 Batch  740/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9567, Loss: 0.0322
# Epoch   3 Batch  750/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9339, Loss: 0.0383
# Epoch   3 Batch  760/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.9538, Loss: 0.0441
# Epoch   3 Batch  770/1077 - Train Accuracy: 0.9494, Validation Accuracy: 0.9336, Loss: 0.0415
# Epoch   3 Batch  780/1077 - Train Accuracy: 0.9297, Validation Accuracy: 0.9521, Loss: 0.0532
# Epoch   3 Batch  790/1077 - Train Accuracy: 0.9184, Validation Accuracy: 0.9492, Loss: 0.0430
# Epoch   3 Batch  800/1077 - Train Accuracy: 0.9434, Validation Accuracy: 0.9556, Loss: 0.0452
# Epoch   3 Batch  810/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9496, Loss: 0.0293
# Epoch   3 Batch  820/1077 - Train Accuracy: 0.9473, Validation Accuracy: 0.9418, Loss: 0.0342
# Epoch   3 Batch  830/1077 - Train Accuracy: 0.9023, Validation Accuracy: 0.9616, Loss: 0.0448
# Epoch   3 Batch  840/1077 - Train Accuracy: 0.9691, Validation Accuracy: 0.9432, Loss: 0.0343
# Epoch   3 Batch  850/1077 - Train Accuracy: 0.9479, Validation Accuracy: 0.9553, Loss: 0.0641
# Epoch   3 Batch  860/1077 - Train Accuracy: 0.9423, Validation Accuracy: 0.9581, Loss: 0.0436
# Epoch   3 Batch  870/1077 - Train Accuracy: 0.9408, Validation Accuracy: 0.9620, Loss: 0.0348
# Epoch   3 Batch  880/1077 - Train Accuracy: 0.9617, Validation Accuracy: 0.9563, Loss: 0.0467
# Epoch   3 Batch  890/1077 - Train Accuracy: 0.9472, Validation Accuracy: 0.9339, Loss: 0.0366
# Epoch   3 Batch  900/1077 - Train Accuracy: 0.9758, Validation Accuracy: 0.9631, Loss: 0.0448
# Epoch   3 Batch  910/1077 - Train Accuracy: 0.9494, Validation Accuracy: 0.9538, Loss: 0.0402
# Epoch   3 Batch  920/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9670, Loss: 0.0325
# Epoch   3 Batch  930/1077 - Train Accuracy: 0.9629, Validation Accuracy: 0.9638, Loss: 0.0324
# Epoch   3 Batch  940/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9517, Loss: 0.0293
# Epoch   3 Batch  950/1077 - Train Accuracy: 0.9721, Validation Accuracy: 0.9602, Loss: 0.0338
# Epoch   3 Batch  960/1077 - Train Accuracy: 0.9531, Validation Accuracy: 0.9577, Loss: 0.0367
# Epoch   3 Batch  970/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9684, Loss: 0.0392
# Epoch   3 Batch  980/1077 - Train Accuracy: 0.9477, Validation Accuracy: 0.9588, Loss: 0.0403
# Epoch   3 Batch  990/1077 - Train Accuracy: 0.9638, Validation Accuracy: 0.9688, Loss: 0.0435
# Epoch   3 Batch 1000/1077 - Train Accuracy: 0.9516, Validation Accuracy: 0.9528, Loss: 0.0416
# Epoch   3 Batch 1010/1077 - Train Accuracy: 0.9691, Validation Accuracy: 0.9538, Loss: 0.0309
# Epoch   3 Batch 1020/1077 - Train Accuracy: 0.9707, Validation Accuracy: 0.9492, Loss: 0.0297
# Epoch   3 Batch 1030/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9425, Loss: 0.0344
# Epoch   3 Batch 1040/1077 - Train Accuracy: 0.9609, Validation Accuracy: 0.9577, Loss: 0.0385
# Epoch   3 Batch 1050/1077 - Train Accuracy: 0.9512, Validation Accuracy: 0.9304, Loss: 0.0328
# Epoch   3 Batch 1060/1077 - Train Accuracy: 0.9652, Validation Accuracy: 0.9446, Loss: 0.0348
# Epoch   3 Batch 1070/1077 - Train Accuracy: 0.9570, Validation Accuracy: 0.9545, Loss: 0.0338
# Epoch   4 Batch   10/1077 - Train Accuracy: 0.9679, Validation Accuracy: 0.9577, Loss: 0.0429
# Epoch   4 Batch   20/1077 - Train Accuracy: 0.9672, Validation Accuracy: 0.9535, Loss: 0.0288
# Epoch   4 Batch   30/1077 - Train Accuracy: 0.9574, Validation Accuracy: 0.9450, Loss: 0.0320
# Epoch   4 Batch   40/1077 - Train Accuracy: 0.9723, Validation Accuracy: 0.9521, Loss: 0.0267
# Epoch   4 Batch   50/1077 - Train Accuracy: 0.9637, Validation Accuracy: 0.9570, Loss: 0.0311
# Epoch   4 Batch   60/1077 - Train Accuracy: 0.9490, Validation Accuracy: 0.9570, Loss: 0.0306
# Epoch   4 Batch   70/1077 - Train Accuracy: 0.9461, Validation Accuracy: 0.9474, Loss: 0.0398
# Epoch   4 Batch   80/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9588, Loss: 0.0277
# Epoch   4 Batch   90/1077 - Train Accuracy: 0.9473, Validation Accuracy: 0.9620, Loss: 0.0397
# Epoch   4 Batch  100/1077 - Train Accuracy: 0.9641, Validation Accuracy: 0.9688, Loss: 0.0334
# Epoch   4 Batch  110/1077 - Train Accuracy: 0.9777, Validation Accuracy: 0.9503, Loss: 0.0257
# Epoch   4 Batch  120/1077 - Train Accuracy: 0.9664, Validation Accuracy: 0.9492, Loss: 0.0370
# Epoch   4 Batch  130/1077 - Train Accuracy: 0.9658, Validation Accuracy: 0.9393, Loss: 0.0327
# Epoch   4 Batch  140/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9403, Loss: 0.0309
# Epoch   4 Batch  150/1077 - Train Accuracy: 0.9535, Validation Accuracy: 0.9595, Loss: 0.0335
# Epoch   4 Batch  160/1077 - Train Accuracy: 0.9656, Validation Accuracy: 0.9553, Loss: 0.0305
# Epoch   4 Batch  170/1077 - Train Accuracy: 0.9754, Validation Accuracy: 0.9421, Loss: 0.0401
# Epoch   4 Batch  180/1077 - Train Accuracy: 0.9723, Validation Accuracy: 0.9474, Loss: 0.0313
# Epoch   4 Batch  190/1077 - Train Accuracy: 0.9625, Validation Accuracy: 0.9585, Loss: 0.0303
# Epoch   4 Batch  200/1077 - Train Accuracy: 0.9594, Validation Accuracy: 0.9691, Loss: 0.0336
# Epoch   4 Batch  210/1077 - Train Accuracy: 0.9721, Validation Accuracy: 0.9414, Loss: 0.0292
# Epoch   4 Batch  220/1077 - Train Accuracy: 0.9712, Validation Accuracy: 0.9464, Loss: 0.0384
# Epoch   4 Batch  230/1077 - Train Accuracy: 0.9673, Validation Accuracy: 0.9492, Loss: 0.0293
# Epoch   4 Batch  240/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9574, Loss: 0.0303
# Epoch   4 Batch  250/1077 - Train Accuracy: 0.9638, Validation Accuracy: 0.9673, Loss: 0.0323
# Epoch   4 Batch  260/1077 - Train Accuracy: 0.9513, Validation Accuracy: 0.9620, Loss: 0.0258
# Epoch   4 Batch  270/1077 - Train Accuracy: 0.9805, Validation Accuracy: 0.9538, Loss: 0.0406
# Epoch   4 Batch  280/1077 - Train Accuracy: 0.9422, Validation Accuracy: 0.9453, Loss: 0.0362
# Epoch   4 Batch  290/1077 - Train Accuracy: 0.9508, Validation Accuracy: 0.9631, Loss: 0.0520
# Epoch   4 Batch  300/1077 - Train Accuracy: 0.9729, Validation Accuracy: 0.9567, Loss: 0.0303
# Epoch   4 Batch  310/1077 - Train Accuracy: 0.9605, Validation Accuracy: 0.9560, Loss: 0.0322
# Epoch   4 Batch  320/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9624, Loss: 0.0346
# Epoch   4 Batch  330/1077 - Train Accuracy: 0.9586, Validation Accuracy: 0.9535, Loss: 0.0356
# Epoch   4 Batch  340/1077 - Train Accuracy: 0.9692, Validation Accuracy: 0.9585, Loss: 0.0304
# Epoch   4 Batch  350/1077 - Train Accuracy: 0.9574, Validation Accuracy: 0.9616, Loss: 0.0345
# Epoch   4 Batch  360/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9599, Loss: 0.0206
# Epoch   4 Batch  370/1077 - Train Accuracy: 0.9706, Validation Accuracy: 0.9627, Loss: 0.0351
# Epoch   4 Batch  380/1077 - Train Accuracy: 0.9742, Validation Accuracy: 0.9531, Loss: 0.0260
# Epoch   4 Batch  390/1077 - Train Accuracy: 0.9371, Validation Accuracy: 0.9606, Loss: 0.0504
# Epoch   4 Batch  400/1077 - Train Accuracy: 0.9578, Validation Accuracy: 0.9609, Loss: 0.0399
# Epoch   4 Batch  410/1077 - Train Accuracy: 0.9363, Validation Accuracy: 0.9691, Loss: 0.0426
# Epoch   4 Batch  420/1077 - Train Accuracy: 0.9785, Validation Accuracy: 0.9634, Loss: 0.0231
# Epoch   4 Batch  430/1077 - Train Accuracy: 0.9746, Validation Accuracy: 0.9531, Loss: 0.0266
# Epoch   4 Batch  440/1077 - Train Accuracy: 0.9547, Validation Accuracy: 0.9535, Loss: 0.0363
# Epoch   4 Batch  450/1077 - Train Accuracy: 0.9672, Validation Accuracy: 0.9471, Loss: 0.0357
# Epoch   4 Batch  460/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9542, Loss: 0.0352
# Epoch   4 Batch  470/1077 - Train Accuracy: 0.9836, Validation Accuracy: 0.9460, Loss: 0.0268
# Epoch   4 Batch  480/1077 - Train Accuracy: 0.9572, Validation Accuracy: 0.9624, Loss: 0.0328
# Epoch   4 Batch  490/1077 - Train Accuracy: 0.9445, Validation Accuracy: 0.9460, Loss: 0.0331
# Epoch   4 Batch  500/1077 - Train Accuracy: 0.9668, Validation Accuracy: 0.9503, Loss: 0.0238
# Epoch   4 Batch  510/1077 - Train Accuracy: 0.9539, Validation Accuracy: 0.9506, Loss: 0.0318
# Epoch   4 Batch  520/1077 - Train Accuracy: 0.9814, Validation Accuracy: 0.9556, Loss: 0.0235
# Epoch   4 Batch  530/1077 - Train Accuracy: 0.9480, Validation Accuracy: 0.9592, Loss: 0.0386
# Epoch   4 Batch  540/1077 - Train Accuracy: 0.9480, Validation Accuracy: 0.9538, Loss: 0.0271
# Epoch   4 Batch  550/1077 - Train Accuracy: 0.9453, Validation Accuracy: 0.9513, Loss: 0.0320
# Epoch   4 Batch  560/1077 - Train Accuracy: 0.9391, Validation Accuracy: 0.9535, Loss: 0.0305
# Epoch   4 Batch  570/1077 - Train Accuracy: 0.9544, Validation Accuracy: 0.9499, Loss: 0.0388
# Epoch   4 Batch  580/1077 - Train Accuracy: 0.9568, Validation Accuracy: 0.9467, Loss: 0.0222
# Epoch   4 Batch  590/1077 - Train Accuracy: 0.9523, Validation Accuracy: 0.9585, Loss: 0.0342
# Epoch   4 Batch  600/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9602, Loss: 0.0293
# Epoch   4 Batch  610/1077 - Train Accuracy: 0.9716, Validation Accuracy: 0.9585, Loss: 0.0325
# Epoch   4 Batch  620/1077 - Train Accuracy: 0.9738, Validation Accuracy: 0.9602, Loss: 0.0290
# Epoch   4 Batch  630/1077 - Train Accuracy: 0.9809, Validation Accuracy: 0.9616, Loss: 0.0258
# Epoch   4 Batch  640/1077 - Train Accuracy: 0.9639, Validation Accuracy: 0.9616, Loss: 0.0297
# Epoch   4 Batch  650/1077 - Train Accuracy: 0.9660, Validation Accuracy: 0.9510, Loss: 0.0348
# Epoch   4 Batch  660/1077 - Train Accuracy: 0.9691, Validation Accuracy: 0.9609, Loss: 0.0262
# Epoch   4 Batch  670/1077 - Train Accuracy: 0.9709, Validation Accuracy: 0.9645, Loss: 0.0290
# Epoch   4 Batch  680/1077 - Train Accuracy: 0.9513, Validation Accuracy: 0.9474, Loss: 0.0284
# Epoch   4 Batch  690/1077 - Train Accuracy: 0.9422, Validation Accuracy: 0.9691, Loss: 0.0334
# Epoch   4 Batch  700/1077 - Train Accuracy: 0.9707, Validation Accuracy: 0.9592, Loss: 0.0233
# Epoch   4 Batch  710/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9698, Loss: 0.0282
# Epoch   4 Batch  720/1077 - Train Accuracy: 0.9638, Validation Accuracy: 0.9634, Loss: 0.0359
# Epoch   4 Batch  730/1077 - Train Accuracy: 0.9574, Validation Accuracy: 0.9606, Loss: 0.0359
# Epoch   4 Batch  740/1077 - Train Accuracy: 0.9715, Validation Accuracy: 0.9361, Loss: 0.0245
# Epoch   4 Batch  750/1077 - Train Accuracy: 0.9500, Validation Accuracy: 0.9499, Loss: 0.0252
# Epoch   4 Batch  760/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9641, Loss: 0.0310
# Epoch   4 Batch  770/1077 - Train Accuracy: 0.9542, Validation Accuracy: 0.9645, Loss: 0.0259
# Epoch   4 Batch  780/1077 - Train Accuracy: 0.9355, Validation Accuracy: 0.9503, Loss: 0.0460
# Epoch   4 Batch  790/1077 - Train Accuracy: 0.9379, Validation Accuracy: 0.9609, Loss: 0.0389
# Epoch   4 Batch  800/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9638, Loss: 0.0312
# Epoch   4 Batch  810/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9709, Loss: 0.0266
# Epoch   4 Batch  820/1077 - Train Accuracy: 0.9727, Validation Accuracy: 0.9524, Loss: 0.0286
# Epoch   4 Batch  830/1077 - Train Accuracy: 0.9219, Validation Accuracy: 0.9670, Loss: 0.0419
# Epoch   4 Batch  840/1077 - Train Accuracy: 0.9730, Validation Accuracy: 0.9602, Loss: 0.0335
# Epoch   4 Batch  850/1077 - Train Accuracy: 0.9613, Validation Accuracy: 0.9588, Loss: 0.0413
# Epoch   4 Batch  860/1077 - Train Accuracy: 0.9688, Validation Accuracy: 0.9677, Loss: 0.0319
# Epoch   4 Batch  870/1077 - Train Accuracy: 0.9585, Validation Accuracy: 0.9727, Loss: 0.0249
# Epoch   4 Batch  880/1077 - Train Accuracy: 0.9777, Validation Accuracy: 0.9549, Loss: 0.0335
# Epoch   4 Batch  890/1077 - Train Accuracy: 0.9691, Validation Accuracy: 0.9638, Loss: 0.0286
# Epoch   4 Batch  900/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9698, Loss: 0.0339
# Epoch   4 Batch  910/1077 - Train Accuracy: 0.9561, Validation Accuracy: 0.9634, Loss: 0.0351
# Epoch   4 Batch  920/1077 - Train Accuracy: 0.9723, Validation Accuracy: 0.9684, Loss: 0.0254
# Epoch   4 Batch  930/1077 - Train Accuracy: 0.9492, Validation Accuracy: 0.9542, Loss: 0.0259
# Epoch   4 Batch  940/1077 - Train Accuracy: 0.9766, Validation Accuracy: 0.9599, Loss: 0.0294
# Epoch   4 Batch  950/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9709, Loss: 0.0243
# Epoch   4 Batch  960/1077 - Train Accuracy: 0.9695, Validation Accuracy: 0.9691, Loss: 0.0300
# Epoch   4 Batch  970/1077 - Train Accuracy: 0.9723, Validation Accuracy: 0.9631, Loss: 0.0216
# Epoch   4 Batch  980/1077 - Train Accuracy: 0.9699, Validation Accuracy: 0.9556, Loss: 0.0270
# Epoch   4 Batch  990/1077 - Train Accuracy: 0.9667, Validation Accuracy: 0.9570, Loss: 0.0325
# Epoch   4 Batch 1000/1077 - Train Accuracy: 0.9520, Validation Accuracy: 0.9641, Loss: 0.0285
# Epoch   4 Batch 1010/1077 - Train Accuracy: 0.9848, Validation Accuracy: 0.9599, Loss: 0.0225
# Epoch   4 Batch 1020/1077 - Train Accuracy: 0.9797, Validation Accuracy: 0.9709, Loss: 0.0187
# Epoch   4 Batch 1030/1077 - Train Accuracy: 0.9730, Validation Accuracy: 0.9616, Loss: 0.0264
# Epoch   4 Batch 1040/1077 - Train Accuracy: 0.9683, Validation Accuracy: 0.9719, Loss: 0.0295
# Epoch   4 Batch 1050/1077 - Train Accuracy: 0.9672, Validation Accuracy: 0.9592, Loss: 0.0223
# Epoch   4 Batch 1060/1077 - Train Accuracy: 0.9750, Validation Accuracy: 0.9695, Loss: 0.0230
# Epoch   4 Batch 1070/1077 - Train Accuracy: 0.9621, Validation Accuracy: 0.9709, Loss: 0.0226
# Model Trained and Saved

# %% [markdown]
# ### Save Parameters
# Save the `batch_size` and `save_path` parameters for inference.

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
# Save parameters for checkpoint
helper.save_params(save_path)

# %% [markdown]
# # Checkpoint

# %%
"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
import tensorflow as tf
import numpy as np
import helper
import problem_unittests as tests

_, (source_vocab_to_int, target_vocab_to_int), (source_int_to_vocab, target_int_to_vocab) = helper.load_preprocess()
load_path = helper.load_params()

# %% [markdown]
# ## Sentence to Sequence
# To feed a sentence into the model for translation, you first need to preprocess it.  Implement the function `sentence_to_seq()` to preprocess new sentences.
#
# - Convert the sentence to lowercase
# - Convert words into ids using `vocab_to_int`
#  - Convert words not in the vocabulary, to the `<UNK>` word id.

# %%
def sentence_to_seq(sentence, vocab_to_int):
    """
    Convert a sentence to a sequence of ids
    :param sentence: String
    :param vocab_to_int: Dictionary to go from the words to an id
    :return: List of word ids
    """
    #Implementation
    ## Convert input sentence to lowercase to reduce noise
    sentence=sentence.lower()
    ## get list of word ids but doing look up in the dictionary for each word
    list_words=[vocab_to_int.get(word, vocab_to_int['<UNK>']) for word in sentence.split(" ")]
    return list_words


"""
DON'T MODIFY ANYTHING IN THIS CELL THAT IS BELOW THIS LINE
"""
tests.test_sentence_to_seq(sentence_to_seq)
# Out:
# Tests Passed

# %% [markdown]
# ## Translate
# This will translate `translate_sentence` from English to French.

# %%
translate_sentence = 'he saw a old yellow truck .'


"""
DON'T MODIFY ANYTHING IN THIS CELL
"""
translate_sentence = sentence_to_seq(translate_sentence, source_vocab_to_int)

loaded_graph = tf.Graph()
with tf.Session(graph=loaded_graph) as sess:
    # Load saved model
    loader = tf.train.import_meta_graph(load_path + '.meta')
    loader.restore(sess, load_path)

    input_data = loaded_graph.get_tensor_by_name('input:0')
    logits = loaded_graph.get_tensor_by_name('predictions:0')
    target_sequence_length = loaded_graph.get_tensor_by_name('target_sequence_length:0')
    source_sequence_length = loaded_graph.get_tensor_by_name('source_sequence_length:0')
    keep_prob = loaded_graph.get_tensor_by_name('keep_prob:0')

    translate_logits = sess.run(logits, {input_data: [translate_sentence]*batch_size,
                                         target_sequence_length: [len(translate_sentence)*2]*batch_size,
                                         source_sequence_length: [len(translate_sentence)]*batch_size,
                                         keep_prob: 1.0})[0]

print('Input')
print('  Word Ids:      {}'.format([i for i in translate_sentence]))
print('  English Words: {}'.format([source_int_to_vocab[i] for i in translate_sentence]))

print('\nPrediction')
print('  Word Ids:      {}'.format([i for i in translate_logits]))
print('  French Words: {}'.format(" ".join([target_int_to_vocab[i] for i in translate_logits])))
# Out:
# INFO:tensorflow:Restoring parameters from checkpoints/dev
# Input
#   Word Ids:      [164, 217, 145, 7, 68, 8, 64]
#   English Words: ['he', 'saw', 'a', 'old', 'yellow', 'truck', '.']
#
# Prediction
#   Word Ids:      [110, 319, 253, 312, 108, 254, 34, 1]
#   French Words: il a vu un camion jaune . <EOS>

# %% [markdown]
# ## Imperfect Translation
# You might notice that some sentences translate better than others.  Since the dataset you're using only has a vocabulary of 227 English words of the thousands that you use, you're only going to see good results using these words.  For this project, you don't need a perfect translation. However, if you want to create a better translation model, you'll need better data.
#
# You can train on the [WMT10 French-English corpus](http://www.statmt.org/wmt10/training-giga-fren.tar).  This dataset has more vocabulary and richer in topics discussed.  However, this will take you days to train, so make sure you've a GPU and the neural network is performing well on dataset we provided.  Just make sure you play with the WMT10 corpus after you've submitted this project.
# ## Submitting This Project
# When submitting this project, make sure to run all the cells before saving the notebook. Save the notebook file as "dlnd_language_translation.ipynb" and save it as a HTML file under "File" -> "Download as". Include the "helper.py" and "problem_unittests.py" files in your submission.
